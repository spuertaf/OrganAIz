# %% [markdown]
# # OrganAIZ
# ## Agente de manejo de tiempo.

# %% [markdown]
# ### Instalación de librerías:

# %% [markdown]
# Para la correcta ejecucion del proyecto primero se deberan de instalar las librerias usadas para la implementacion del mismo.

# %%
# !virtualenv temp
#!virtualenv -p python3.6 temp
# !source temp/bin/activate

# !pip install anytree pandas
# !pip install pytholog
# !apt install swi-prolog
# !pip install pykeen
# !pip install -U scikit-fuzzy
# !pip install sklearn
# !pip install matplotlib
# !pip install SpeechRecognition
# !pip install tweepy
# !pip install google-auth
# !pip install google-auth-oauthlib
# !pip install google-auth-httplib2
# !pip install google-api-python-client
# !pip install --upgrade google-api-python-client
# !pip install ipywidgets
# !pip install dash
# !pip install streamlit
# !pip install PySimpleGUI
# !pip install pyqt5
# Out:
# created virtual environment CPython3.10.7.final.0-64 in 1139ms
#   creator CPython3Posix(dest=/Users/makata/Documents/02_INTEL_ARTIFICIAL/PROYECTO/OrganAIz/temp, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/Users/makata/Library/Application Support/virtualenv)
#     added seed packages: pip==22.2.2, setuptools==65.3.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# Requirement already satisfied: anytree in /Users/makata/anaconda3/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: pandas in /Users/makata/anaconda3/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from anytree) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytholog in /Users/makata/anaconda3/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: more-itertools in /Users/makata/anaconda3/lib/python3.10/site-packages (from pytholog) (9.1.0)
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# Requirement already satisfied: pykeen in /Users/makata/anaconda3/lib/python3.10/site-packages (1.10.1)
# Requirement already satisfied: rexmex>=0.1.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.1.3)
# Requirement already satisfied: docdata in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.0.3)
# Requirement already satisfied: torch-max-mem>=0.0.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.0.5)
# Requirement already satisfied: requests in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (2.28.1)
# Requirement already satisfied: scikit-learn in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (1.2.2)
# Requirement already satisfied: click in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (8.1.3)
# Requirement already satisfied: typing-extensions in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (4.5.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (1.10.1)
# Requirement already satisfied: torch>=1.10 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (2.0.0)
# Requirement already satisfied: more-click in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.1.2)
# Requirement already satisfied: numpy in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (1.24.2)
# Requirement already satisfied: tabulate in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.9.0)
# Requirement already satisfied: pystow>=0.4.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.5.0)
# Requirement already satisfied: pandas>=1.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (2.0.0)
# Requirement already satisfied: protobuf<4.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (3.20.3)
# Requirement already satisfied: torch-ppr>=0.0.7 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.0.8)
# Requirement already satisfied: optuna>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (3.1.1)
# Requirement already satisfied: click-default-group in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (1.2.2)
# Requirement already satisfied: more-itertools in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (9.1.0)
# Requirement already satisfied: pyyaml in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (6.0)
# Requirement already satisfied: class-resolver>=0.3.10 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.4.2)
# Requirement already satisfied: dataclasses-json in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (0.5.7)
# Requirement already satisfied: tqdm in /Users/makata/anaconda3/lib/python3.10/site-packages (from pykeen) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (23.0)
# Requirement already satisfied: cmaes>=0.9.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (0.9.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (2.0.10)
# Requirement already satisfied: colorlog in /Users/makata/anaconda3/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (6.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (1.10.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: sympy in /Users/makata/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pykeen) (1.11.1)
# Requirement already satisfied: networkx in /Users/makata/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pykeen) (3.1)
# Requirement already satisfied: jinja2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pykeen) (3.1.2)
# Requirement already satisfied: filelock in /Users/makata/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pykeen) (3.9.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dataclasses-json->pykeen) (0.8.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dataclasses-json->pykeen) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dataclasses-json->pykeen) (1.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests->pykeen) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests->pykeen) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests->pykeen) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests->pykeen) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from scikit-learn->pykeen) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from scikit-learn->pykeen) (1.2.0)
# Requirement already satisfied: Mako in /Users/makata/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.2.4)
# Requirement already satisfied: six>=1.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen) (2.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jinja2->torch>=1.10->pykeen) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/makata/anaconda3/lib/python3.10/site-packages (from sympy->torch>=1.10->pykeen) (1.3.0)
# Requirement already satisfied: scikit-fuzzy in /Users/makata/anaconda3/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from scikit-fuzzy) (1.24.2)
# Requirement already satisfied: networkx>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from scikit-fuzzy) (3.1)
# Requirement already satisfied: scipy>=0.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from scikit-fuzzy) (1.10.1)
# Requirement already satisfied: sklearn in /Users/makata/anaconda3/lib/python3.10/site-packages (0.0.post4)
# Requirement already satisfied: matplotlib in /Users/makata/anaconda3/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/makata/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: SpeechRecognition in /Users/makata/anaconda3/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from SpeechRecognition) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: tweepy in /Users/makata/anaconda3/lib/python3.10/site-packages (4.14.0)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: google-auth in /Users/makata/anaconda3/lib/python3.10/site-packages (2.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth) (5.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.5.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/makata/anaconda3/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib) (2.17.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: six>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.28.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.5.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Requirement already satisfied: google-auth-httplib2 in /Users/makata/anaconda3/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: httplib2>=0.15.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: six in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth-httplib2) (1.16.0)
# Requirement already satisfied: google-auth in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth-httplib2) (2.17.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth->google-auth-httplib2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth->google-auth-httplib2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth->google-auth-httplib2) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth->google-auth-httplib2) (0.5.0)
# Requirement already satisfied: google-api-python-client in /Users/makata/anaconda3/lib/python3.10/site-packages (2.86.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (2.17.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: google-api-python-client in /Users/makata/anaconda3/lib/python3.10/site-packages (2.86.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (2.17.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Requirement already satisfied: six>=1.9.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: ipywidgets in /Users/makata/anaconda3/lib/python3.10/site-packages (8.0.6)
# Requirement already satisfied: ipython>=6.1.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipywidgets) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipywidgets) (4.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipywidgets) (6.23.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: psutil in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: nest-asyncio in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: appnope in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: packaging in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: pickleshare in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: pexpect>4.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: stack-data in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: decorator in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/makata/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (2.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/makata/anaconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/makata/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /Users/makata/anaconda3/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: dash in /Users/makata/anaconda3/lib/python3.10/site-packages (2.9.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dash) (5.14.1)
# Requirement already satisfied: dash-table==5.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from dash) (2.3.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.3.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Flask>=1.0.4->dash) (2.3.4)
# Requirement already satisfied: click>=8.1.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Flask>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: packaging in /Users/makata/anaconda3/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (2.1.1)
# Requirement already satisfied: streamlit in /Users/makata/anaconda3/lib/python3.10/site-packages (1.22.0)
# Requirement already satisfied: tornado>=6.0.3 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (6.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: tzlocal>=1.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (4.3)
# Requirement already satisfied: packaging>=14.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (23.0)
# Requirement already satisfied: python-dateutil in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: toml in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: numpy in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (1.24.2)
# Requirement already satisfied: requests>=2.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: blinker>=1.0.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: pyarrow>=4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: click>=7.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: protobuf<4,>=3.12 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: altair<5,>=3.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: cachetools>=4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (6.6.0)
# Requirement already satisfied: pympler>=0.9 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: pandas<3,>=0.25 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (2.0.0)
# Requirement already satisfied: validators>=0.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/makata/anaconda3/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: jinja2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: entrypoints in /Users/makata/anaconda3/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.4->streamlit) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/makata/anaconda3/lib/python3.10/site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from rich>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/makata/anaconda3/lib/python3.10/site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/makata/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (22.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/makata/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: PySimpleGUI in /Users/makata/anaconda3/lib/python3.10/site-packages (4.60.4)
# Requirement already satisfied: pyqt5 in /Users/makata/anaconda3/lib/python3.10/site-packages (5.15.9)
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in /Users/makata/anaconda3/lib/python3.10/site-packages/PyQt5_sip-12.11.0-py3.10-macosx-10.9-x86_64.egg (from pyqt5) (12.11.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/makata/anaconda3/lib/python3.10/site-packages (from pyqt5) (5.15.2)

# %% [markdown]
# ### Importación de librerías:

# %%
import ssl
import csv
import numpy as np
import pandas as pd
from anytree import NodeMixin, RenderTree
import pytholog as pl 
import datetime
import dateparser
import math
import itertools
import tweepy
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error as mse, silhouette_score, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.metrics import r2_score
import speech_recognition as sr
import ipywidgets as widgets

import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.express as px

import PySimpleGUI as sg

# %% [markdown]
# ## Funciones auxiliares

# %%
def convertir_hora_a_minutos(hora) :
    # Dividir la hora y los minutos
    partes = hora.split(':')
    horas = int(partes[0])
    minutos = int(partes[1])

    # Calcular la suma de minutos
    suma_minutos = horas * 60 + minutos

    return suma_minutos

def reorganizar_csv_por_task_id(csv_file):
    df = pd.read_csv(csv_file)
    df = df.sort_values(by=["TaskID"], ascending=True)
    df.to_csv(csv_file, index=False)

# %% [markdown]
# ## Agregar nuevas tareas pendientes usando percepción de voz:

# %% [markdown]
# Vamos a agregar una funcionalidad al agente para que le puedas dictar una tarea y el agente la guarde como tarea y la añada al pool de tareas pendientes.
#
# Formato para guardar una nueva tarea:
# - Name
# - TaskType (El Id)
# - AvgTime
# - Urgency
# - TimeStart
# - Deadline
# - Location
# - IsHobby
# - Recurrency
# - BestOn
# - Involves
#
# Datos que asigna el agente:
# - TaskID
# - Parent

# %% [markdown]
# Procesamiento de audio hardcoded

# %%
# Procesamiento de los audios.

r = sr.Recognizer()

audio_file_name = "./audio_files/tarea_nombre.wav"
audio_file_taskType = "./audio_files/taskType.wav"
audio_file_avgTime = "./audio_files/duracion.wav"
audio_file_urgency = "./audio_files/urgencia.wav"
audio_file_timeStart = "./audio_files/timeStart.wav"
audio_file_deadline = "./audio_files/deadline.wav"
audio_file_location = "./audio_files/location.wav"
audio_file_isHobby = "./audio_files/isHobby.wav"
audio_file_recurrency = "./audio_files/recurrency.wav"
audio_file_bestOn = "./audio_files/bestOn.wav"
audio_file_involves = "./audio_files/involves.wav"

# PARSING TASK NAME

with sr.AudioFile(audio_file_name) as source:
    audio = r.record(source)

taskName = r.recognize_google(audio, language="es-ES")

print("Nombre de la tarea: "+taskName)

# PARRSING DE TASKTYPE

with sr.AudioFile(audio_file_taskType) as source:
    audio = r.record(source)

taskType = r.recognize_google(audio, language="es-ES")
print(taskType)

# Revisamos que los datos capturados sean un digito numerico:
if taskType.isdigit():
    taskType = int(taskType)
else:
    print("La cadena no contiene solo números")

print(f"--> El ID de el tipo de tarea es {taskType}")


# PARSING DE AVGTIME

with sr.AudioFile(audio_file_avgTime) as source:
    audio = r.record(source)

taskAvgTime = r.recognize_google(audio, language="es-ES")
print(taskAvgTime)

# Revisamos que los datos capturados sean un digito numerico:
if taskAvgTime.isdigit():
    taskAvgTime = int(taskAvgTime)
else:
    print("La cadena no contiene solo números")

print(f"--> El tiempo promedio es {taskAvgTime} minutos")


# PARSING DE URGENCY

with sr.AudioFile(audio_file_urgency) as source:
    audio = r.record(source)

taskUrgency = r.recognize_google(audio, language="es-ES")
print(taskUrgency)

# Revisamos que los datos capturados sean un digito numerico:
if taskUrgency.isdigit():
    taskUrgency = int(taskUrgency)
else:
    print("La cadena no contiene solo números")

print(f"--> La urgencia es {taskUrgency}")



# PARSING DE TIME START

with sr.AudioFile(audio_file_timeStart) as source:
    audio = r.record(source)

tasktimeStart = r.recognize_google(audio, language="es-ES")
print(tasktimeStart)

# Conversion de la hora

# Convertir el texto en una hora legible por datetime.strptime()
dt_str = dateparser.parse(tasktimeStart).strftime("%H:%M")

# Convertir la hora en formato string a un objeto datetime
dt = datetime.datetime.strptime(dt_str, "%H:%M")


# Calcular los minutos transcurridos desde que inició el día
minutes = dt.hour * 60 + dt.minute

print(f"--> La hora de inicio es {dt.strftime('%H:%M:%S')}, que equivale a {minutes} minutos desde que inició el día.")


# PARSING DE DEADLINE

with sr.AudioFile(audio_file_deadline) as source:
    audio = r.record(source)

taskDeadline = r.recognize_google(audio, language="es-ES")
print(taskDeadline)

# Revisamos que los datos capturados sean un digito numerico:
if taskDeadline.isdigit():
    taskDeadline = int(taskDeadline)
else:
    print("La cadena no contiene solo números")

print(f"--> La deadline es {taskDeadline}")


# PARSING DE LOCATION

with sr.AudioFile(audio_file_location) as source:
    audio = r.record(source)

taskLocation = r.recognize_google(audio, language="es-ES")
print(taskLocation)

print(f"--> La ubicación de la tarea es en {taskDeadline}")


# PARSING DE IS HOBBY

with sr.AudioFile(audio_file_isHobby) as source:
    audio = r.record(source)

taskIsHobby = r.recognize_google(audio, language="es-ES")
print(taskIsHobby)

# Conversión a booleano en formato inglés
if taskIsHobby.lower() == "verdadero":
    isHobby = True
elif taskIsHobby.lower() == "falso":
    isHobby = False
else:
    isHobby = False

print(f"--> La tarea es hobby? {taskIsHobby}")


# PARSING DE RECURRENCY

with sr.AudioFile(audio_file_recurrency) as source:
    audio = r.record(source)

taskRecurrency = r.recognize_google(audio, language="es-ES")
print(taskRecurrency)

# Revisamos que los datos capturados sean un digito numerico:
if taskRecurrency.isdigit():
    taskRecurrency = int(taskRecurrency)
else:
    print("La cadena no contiene solo números")

print(f"--> La recurrencia es {taskRecurrency}")


# PARSING DE BEST ON 

with sr.AudioFile(audio_file_bestOn) as source:
    audio = r.record(source)

taskBestOn = r.recognize_google(audio, language="es-ES")
print(taskBestOn)

print(f"--> El mejor momento para realizar la tarea es:  {taskRecurrency}")



# PARSING DE INVOLVES

with sr.AudioFile(audio_file_involves) as source:
    audio = r.record(source)

taskInvolves = r.recognize_google(audio, language="es-ES")
print(taskInvolves)

print(f"--> La tarea involucra a alguien mas? {taskInvolves}")
# Out:
# Nombre de la tarea: aspirar la casa
# 3
# --> El ID de el tipo de tarea es 3
# 40
# --> El tiempo promedio es 40 minutos
# 5
# --> La urgencia es 5
# 10:25
# --> La hora de inicio es 10:25:00, que equivale a 625 minutos desde que inició el día.
# 6
# --> La deadline es 6
# mi casa
# --> La ubicación de la tarea es en 6
# falso
# --> La tarea es hobby? falso
# Tris
# La cadena no contiene solo números
# --> La recurrencia es Tris
# mañana
# --> El mejor momento para realizar la tarea es:  Tris
# no
# --> La tarea involucra a alguien mas? no

# %% [markdown]
# Procedemos a guardar los datos procesados como una entrada en el csv correspondiente a una nueva actividad.

# %%
# Abre el archivo CSV en modo de lectura
with open('./audio_files/audio_Tasks.csv', mode='r') as archivo_csv:
    # Crea un objeto csv.reader
    reader = csv.reader(archivo_csv)
    # Cuenta el número de líneas en el archivo CSV (restando la primera línea de encabezados)
    num_lines = len(list(reader))

# Abre el archivo CSV en modo de escritura
with open('./audio_files/audio_Tasks.csv', mode='a', newline='') as archivo_csv:
    # Asigna el valor de var1 como el número de líneas en el archivo CSV
    taskID = num_lines
    # Crea un objeto csv.writer
    writer = csv.writer(archivo_csv)
    # Escribe la línea en el orden que necesitamos para que coincida con el formato preestablecido
    writer.writerow([taskID, taskType, taskName , taskAvgTime, taskUrgency, tasktimeStart, taskDeadline, taskLocation, taskIsHobby, taskRecurrency, taskBestOn, taskInvolves])

# %% [markdown]
# ## Convertir cualquier lista de tareas (CSV) en un árbol:

# %% [markdown]
# Este metodo convierte cualquier lista de tareas sin orden en un arbol, para que el algoritmo de busqueda pueda luego seleccionar el mejor camino dentro del arbol.
# Como entrada a modo de ejemplo pondremos un CSV de tareas sin orden, y a la salida el agente habrá ordenado las tareas en un arbol.

# %%
#Ordenar tareas en modo de arbol.

df = pd.read_csv("ordenar_tareas/tasksUnordered.csv") # leer el archivo csv original

df = df.sort_values(by=["TimeStart"]) # ordenar las tareas por su tiempo de inicio

parents = {} #diccionario para almacenar los padres de cada tarea

# recorrer cada tarea
for i, row in df.iterrows():
    # encontrar el tiempo de finalización de la tarea actual
    current_end_time = row["TimeStart"] + row["AvgTime"]
    # inicializar la distancia más cercana como infinito
    closest_distance = float("inf")
    # inicializar el padre más cercano como None
    closest_parent = None
    # buscar el padre más cercano en las tareas anteriores
    for j in range(i):
        # encontrar el tiempo de finalización de la tarea anterior
        previous_end_time = df.iloc[j]["TimeStart"] + df.iloc[j]["AvgTime"]
        # si la tarea anterior termina antes de que comience la tarea actual
        # y la distancia entre la tarea anterior y la actual es menor que la distancia más cercana actual
        # actualizar el padre más cercano y la distancia más cercana
        if previous_end_time <= row["TimeStart"] and (row["TimeStart"] - previous_end_time) < closest_distance:
            closest_distance = row["TimeStart"] - previous_end_time
            closest_parent = int(df.iloc[j]["TaskID"])
    # si se encontró un padre cercano, agregarlo al diccionario de padres
    if closest_parent is not None:
        parents[int(row["TaskID"])] = int(closest_parent)

# agregar la columna Parent al dataframe
df["Parent"] = df["TaskID"].map(parents)

# guardar el dataframe en un nuevo archivo csv
df.to_csv("ordenar_tareas/tasksOrdered.csv", index=False)

# %% [markdown]
# ## Calcular la urgencia de cada tarea con redes de creencias:

# %% [markdown]
# Este fragmento de código calcula la urgencia de cada tarea usando Redes de Creencias. anteriormente la urgencia se calculaba holisticamente, pero mediante este metodo logramos que tenga valores mas logicos y coherentes para ser usados como insumo luego.

# %%
"""
Código que calcula la urgencia de cada tarea usando Redes de Creencias.
Definir las funciones de creencia para cada factor:
"""

def creencia_avg_time(avg_time:int) -> float:
    """
    Creencia triangular para que las tareas con tiempo promedio de terminacion
    mas bajos sean prioriozadas. 
    
    Args:
        avg_time (int): Tiempo promedio que se demora en ejecutar y completar la tarea (minutos).
        
    Returns:
        float: Peso de la tarea de acuerdo con su tiempo promedio de terminacion, 
        entre mas se demore mas pequeño va a ser el peso que esta posea.  
    """
    if avg_time < 20:
        return 0.2
    elif avg_time < 40:
        return (avg_time - 10) / 10
    elif avg_time < 60:
        return 1 - (avg_time - 20) / 10
    else:
        return 0.2



def creencia_deadline(deadline:int) -> float:
    """
    Funcion de Creencia inversa para que las tareas que tengan una fecha limite
    mas pequeña (mas cerca del limite) sean priorizadas.
    Los valores más bajos tendran más prioridad y los valores más altos tendran menos prioridad.
    
    Args:
        deadline (int): Numero de dias que faltan para la fecha limite de la tarea. 
    
    Returns:
        float: Peso de la tarea de acuerdo con su fecha limite, 
        entre mas pequeña sea la fecha limite mas grande va a ser el peso de la tarea. 
    """
    if deadline < 1:
        return 1
    elif deadline < 5:
        return 1 - (deadline - 1) / 4
    elif deadline < 10:
        return 0.5 - (deadline - 5) / 10
    else:
        return 0



def creencia_is_hobby(is_hobby:bool) -> float:
    """
    Funcion de creencia que baja un poco la prioridad de una tarea si esta es un hobby.
    
    Args:
        is_hobby (bool): Si la tarea es o no un hobby.
        
    Returns:
        float: Peso de la tarea si la misma es o no un hobby.
    """
    if is_hobby:
        return 0.5
    else:
        return 1



def calcular_urgencia(avg_time:int, deadline:int, is_hobby:bool) -> float:
    """
    Construccion de una red de creencias que combine las funciones de creencia:
    creencia_avg_time, creencia_deadline y creencia_is_hobby usando una regla del producto.
    
    Args:
        avg_time (int): Tiempo promedio que se demora en ejecutar la tarea
        deadline (int): Numero de dias que faltan para la fecha limite de la tarea. 
        is_hobby (bool): Si la tarea es o no un hobby.
        
    Returns:
        float: Peso total asignado a la tarea, mediante el calculo de los diferentes
        pesos de sus artibutos avg_time, deadline e isHobby por medio de las funciones
        creencia_avg_time, creencia_deadline y creencia_is_hobby usando una regla del producto.
    """
    creencia_avg_time_res = creencia_avg_time(avg_time)
    creencia_deadline_res = creencia_deadline(deadline)
    creencia_is_hobby_res = creencia_is_hobby(is_hobby)
    urgencia_calc = creencia_avg_time_res * creencia_deadline_res * creencia_is_hobby_res
    return urgencia_calc



def escalar_urgencia(urgencia_calc:float) -> float:
    """
    Escalar la urgencia dentro de un intervalo de valores aceptados; [1,10].

    Args:
        urgencia_calc (float): Peso total asignado a la tarea, mediante el calculo de los diferentes
                               pesos de sus artibutos avg_time, deadline e isHobby por medio de las funciones
                               creencia_avg_time, creencia_deadline y creencia_is_hobby usando una regla del producto.

    Returns:
        float: Urgencia escalada al intervalo definido: maximo la urgencia puede tomar un valor de 10
        y minimo la urgencia puede tomar una valor de 1, [1,10].
    """
    urgencia_min = 1
    urgencia_max = 10
    urgencia = urgencia_min + ((urgencia_calc - 0) / (1 - 0)) * (urgencia_max - urgencia_min)
    return round(urgencia, 2)



df = pd.read_csv("urgencia/tareas.csv") # Leer el CSV

# Calcular la urgencia para cada tarea y escalar el valor entre 1 y 10 con máximo 2 espacios decimales
df["Urgency"] = df.apply(lambda row: escalar_urgencia(calcular_urgencia(row["AvgTime"], row["Deadline"], row["IsHobby"])), axis=1)

df.to_csv("urgencia/tareas_con_urgencia.csv", index=False) # Guardar el CSV con la nueva columna

# %% [markdown]
# ## Creamos la clase Tarea (Almacena las propiedades de c/actividad):

# %% [markdown]
# Aquí vamos a crear la clase Task y TaskClass, que son los ladrillos constructores, las unidades mínimas con las que estaremos analizando cada tarea y armando nuestras soluciones.

# %%
class Task:
    def __init__(self, id:int, taskType:int, name:str, avgTime:int, 
                 timeStart:int, deadline:int, urgency:float, location:str, 
                 isHobby:bool, recurrency:int, bestOn:str, involves:str):
        """
        Constructor del objeto tarea.

        Args:
            id (int): Identificador unico de la tarea
            taskType (int): Categoria de la tarea a completar.
                1- Alimentación​,
                2- Aseo​,
                3- Actividad de Mascota​,
                4- Estudio​,
                5- Salud Física​,
                6- Plantas​,
                7- Gustos​,
                8- Actividad Social​,
                9- Actividad de Autocuidado y Orden.
            name (str): Nombre de la tarea
            avgTime (int): Tiempo promedio que se demora en ejecutar y completar la tarea (minutos).
            timeStart (int): _description_
            deadline (int): Numero de dias que faltan para la fecha limite de la tarea. 
            urgency (float): Nivel de prioridad
            location (str): Lugar fisico en el cual se realizara la tarea.
            isHobby (bool): Si la tarea es o no un hobby.
            recurrency (int): Cuantos dias en la semana suele repetirse la tarea.
            bestOn (str): Mejor en la mañana o en la tarde.
            involves (str): Sujetos terceros que involucra la tarea.
        """
        self.id=id
        self.taskType=taskType
        self.name=name
        self.avgTime=avgTime
        self.timeStart=timeStart
        self.deadline=deadline
        self.location=location
        self.urgency=urgency
        self.isHobby=isHobby
        self.recurrency=recurrency
        self.bestOn=bestOn
        self.involves=involves
        self.prioridad=""
        self.onPath=False
    
    
    
    def __str__(self) -> str:
        """
        To String del objeto Task. 
        Llevar los atributos del objeto a una forma legible a la
        hora de imprimir el objeto.

        Args:
            self (Task): Instancia de la clase Task.
        
        Returns:
            str: Representacion como texto del objeto Task.
        """
        return f"id: {self.id}, taskType: {self.taskType}, name: {self.name}, avgTime: {self.avgTime}, timeStart:{self.timeStart},deadline:{self.deadline},location:{self.location} urgency: {self.urgency}, isHobby: {self.isHobby}, recurrency:{self.recurrency}, bestOn:{self.bestOn} "



class TaskClass(Task, NodeMixin):  # Add Node feature
    def __init__(self,id:int, taskType:int, name:str, avgTime:int, 
                 timeStart:int, deadline:int, urgency:float, location:str, 
                 isHobby:bool, recurrency:int, bestOn:str, involves:str, 
                 parent:NodeMixin=None, children:NodeMixin=None):
        """
        Constructor del objeto Tarea como nodo de un arbol.

        Args:
            id (int): Identificador unico de la tarea
            taskType (int): Categoria de la tarea a completar.
                1- Alimentación​,
                2- Aseo​,
                3- Actividad de Mascota​,
                4- Estudio​,
                5- Salud Física​,
                6- Plantas​,
                7- Gustos​,
                8- Actividad Social​,
                9- Actividad de Autocuidado y Orden.
            name (str): Nombre de la tarea
            avgTime (int): Tiempo promedio que se demora en ejecutar y completar la tarea (minutos).
            timeStart (int): _description_
            deadline (int): Numero de dias que faltan para la fecha limite de la tarea. 
            urgency (float): Nivel de prioridad
            location (str): Lugar fisico en el cual se realizara la tarea.
            isHobby (bool):  Si la tarea es o no un hobby.
            recurrency (int): Cuantos dias en la semana suele repetirse la tarea.
            bestOn (str): Mejor en la mañana o en la tarde.
            involves (str): Sujetos terceros que involucra la tarea.
            parent (NodeMixin, optional): _description_. Defaults to None.
            children (NodeMixin, optional): _description_. Defaults to None.
        """
        super().__init__(id, taskType, name, avgTime, timeStart, deadline, urgency, location, isHobby, recurrency, bestOn, involves) #llamada al constructor padre
        self.parent = parent
        self.onPath=False
        if children:
            self.children = children

# %% [markdown]
# Esta es la clase auxiliar choice que nos sirve en el recorrido de la mejor solución.

# %%
class Choice():
    def __init__(self, move, urgency):
        self.move = move
        self.urgency = urgency



    def __str__(self):
        """
        To String del objeto Choice. 
        Llevar los atributos del objeto a una forma legible a la
        hora de imprimir el objeto.

        Args:
            self (Choice): Instancia de la clase Choice.
        
        Returns:
            str: Representacion como texto del objeto Choice.
        """
        return self.move + ": " + str(self.urgency)

# %% [markdown]
# ## Inicializamos el Agente:

# %% [markdown]
# Aquí tenemos el constructor de nuestro agente y clases relacionadas con su estructura básica.

# %%
#definamos la estructura más básica de nuestro agente
#la cual podrá ir creciendo según se definan nuevas características


class ScheduleAgent:
  def __init__(self, name:str, age:int, gender:str, taskList:pd.DataFrame, comments):
    """
    Constructor del objeto agente

    Args:
        name (str): Nombre del usuario
        age (int): Edad del usuario
        gender (str): Genero del usuario
        taskList (pd.DataFrame): Lista de tareas del usuario
        comments (_type_): _description_
    """
    self.name = name
    self.age = age
    self.gender = gender
    self.taskList = taskList
    self.notification = comments
    self.comments = comments
    self.rootNode = self.buildTree() #creo el arbol al inicializar el objeto
    
    
  
  def getNodesList(self) -> list:
    """
    Crear una lista de nodos del arbol de tareas de acuerdo a las
    tareas almacenadas en un archivo CSV.

    Args:
        self (ScheduleAgent): Instancia de la clase ScheduleAgent.

    Returns:
        list: Lista de nodos del arbol de tareas, cada nodo representa una tarea.
    """
    nodeList = []
    for i in range(0, len(self.taskList["Name"])):
        nodeList.append(TaskClass(
            id=self.taskList["TaskID"][i],
            taskType = self.taskList["TaskType"][i],
            name = self.taskList["Name"][i],
            avgTime = self.taskList["AvgTime"][i],
            timeStart = self.taskList["TimeStart"][i],
            deadline = self.taskList["Deadline"][i],
            urgency = self.taskList["Urgency"][i],
            location = self.taskList["Location"][i],
            isHobby = self.taskList["IsHobby"][i],
            recurrency = self.taskList["Recurrency"][i],
            bestOn = self.taskList["BestOn"][i],
            involves = self.taskList["Involves"][i],
        ))
    return nodeList
  
  
  
  def setParentNodes(self, nodeList:list) -> TaskClass:
    """
    Colocar a cada uno de los nodos del arbol de tareas su respectivo nodo padre.

    Args:
        self (ScheduleAgent): Instancia de la clase ScheduleAgent.
        nodeList (list): Lista de nodos del arbol de tareas, cada nodo representa una tarea.

    Returns:
        TaskClass: Nodo raiz del arbol de tareas, desde el nodo raiz se puede recorrer la totalidad del arbol.
    """
    for i in range(1, len(nodeList)):
        node = nodeList[i]
        node.parent = nodeList[(int(self.taskList["Parent"][i]))-1]
    return nodeList[0] #retorno root del arbol ya que desde root lo puedo recorrer todo

  
  
  def buildTree(self) -> TaskClass: 
    """
    Armar el arbol de tareas.
    En primera instancia crea una lista de nodos de tareas para 
    despues asignarles su respectivo nodo padre.

    Args:
        self (ScheduleAgent): Instancia de la clase ScheduleAgent.

    Returns:
        TaskClass: Nodo raiz del arbol de tareas, desde el nodo raiz se puede recorrer la totalidad del arbol.
    """
    nodeList = self.getNodesList()
    rootNode = self.setParentNodes(nodeList)
    return rootNode #retorno root del arbol ya que desde root lo puedo recorrer todo
    
    
    
  def printTaskTree(self) -> None:
    """
    Imprimir por completo el arbol de tareas. 
    
    Args:
        self (ScheduleAgent): Instancia de la clase ScheduleAgent.
    """
    for pre, fill, node in RenderTree(self.rootNode):
        print("%s%s" % (pre, node.name))   
  
  
  
  def miniMax(self, rootNode:Task, isMax:bool) -> Choice:
    """
    Algoritmo de busqueda miniMax para determinar la mayor cantidad de tareas de la mayor urgencia posible
    a completar en el minimo tiempo posible.

    Args:
        self (ScheduleAgent): Instancia de la clase ScheduleAgent.
        rootNode (Task): Nodo raiz del arbol de tareas, desde el nodo raiz se puede recorrer la totalidad del arbol.
        isMax (bool): ?

    Returns:
        Choice: Eleccion de rama y nodo del algortimo miniMax
    """
    children = rootNode.children
    try:
        l_choice = self.miniMax(children[0], not isMax)
        r_choice = self.miniMax(children[1], not isMax)

        if (isMax):
            if (l_choice.urgency > r_choice.urgency):
                return Choice("left", l_choice.urgency)
            else:
                return Choice("right", r_choice.urgency)
        else:
            if (l_choice.urgency < r_choice.urgency):
                return Choice("left", l_choice.urgency)
            else:
                return Choice("right", r_choice.urgency) 
    except IndexError:
        return Choice("end", self.rootNode.urgency)

# %% [markdown]
# Estructura para guardar el horario.

# %%
horario = {}

def agregar_tarea(node):
    horario[node.name] = node

# %% [markdown]
# ## Calculamos el mejor horario posible usando Minimax

# %% [markdown]
# Inicializamos el agente con un usuario ejemplo y calculamos la mejor solución para su horario.

# %%
username = ' '
age = ' '
gender = ' '

#inicializando el agente para el usuario
myAgent = ScheduleAgent(name=username,
                        age=age,
                        gender=gender,
                        taskList=pd.read_csv('agentTaskList.csv'),
                        #taskList=pd.read_csv('./UI/tareas_orden.csv'),
                        comments = "")

def crearHorario():

    isMax = True
    currentNode = myAgent.rootNode
    agregar_tarea(currentNode)

    print("Comenzamos nuestro recorrido en el nodo: "+str(currentNode.name)+", con una urgencia de: "+str(currentNode.urgency))
    currentNode.onPath=True

    while (True):
        # run minimax on current node
        agentChoice = myAgent.miniMax(currentNode, isMax) 
        
        # make choice based on minimax search
        if (agentChoice.move == "left"):
            print ("Nos movemos a la izquierda con una urgencia de: " + str(currentNode.children[0].urgency)+ ", a la tarea: "+str(currentNode.children[0].name))
            currentNode.children[0].onPath=True
            currentNode = currentNode.children[0]
            agregar_tarea(currentNode)
        elif (agentChoice.move == "right"):
            print ("Nos movemos a la derecha con una urgencia de: " + str(currentNode.children[1].urgency)+ ", a la tarea: "+str(currentNode.children[1].name))
            currentNode.children[1].onPath=True
            currentNode = currentNode.children[1]
            agregar_tarea(currentNode)
        elif (agentChoice.move == "end"):
            print ("Hemos llegado al final del mejor recorrido")
            break

crearHorario()
# Out:
# Comenzamos nuestro recorrido en el nodo: desayunar, con una urgencia de: 5
# Nos movemos a la derecha con una urgencia de: 5, a la tarea: sacar al perro
# Nos movemos a la derecha con una urgencia de: 7, a la tarea: regar plantas
# Nos movemos a la derecha con una urgencia de: 6, a la tarea: jugar con el perro
# Hemos llegado al final del mejor recorrido

# %% [markdown]
# Creamos estas estructuras de tipo diccionario para poder manejar las Tareas con mas facilidad.

# %%
# PARA ORGANIZAR LAS TAREAS SEGUN SUS ATRIBUTOS.

dictTasks = {}
dictHobbies = {}
dictHabits = {}


# METODO PARA AÑADIR LOS TASKS
def classifyTasks(node):
    dictTasks[node.name] = node
    if node.isHobby == True: 
        dictHobbies[node.name] = node
    if node.recurrency >= 5: 
        dictHabits[node.name] = node
    for node in node.descendants:
            if isinstance(node, Task):
                dictTasks[node.name] = node
                if node.isHobby == True: 
                    dictHobbies[node.name] = node
                if node.recurrency >= 5: 
                    dictHabits[node.name] = node

               
classifyTasks(myAgent.rootNode)

# %% [markdown]
# Código auxiliar para visualizar el horario de una mejor manera.

# %%
def pass_schedule_to_df(horario:dict):
    schedule_df = pd.DataFrame(columns = ["Avg Time to Complete",
                                          "Task Urgency",
                                          "Is it Hobby",
                                          "Task Location",
                                          "Task Recurrency"],
                               index = list(horario.keys()))
    for key in horario.keys():
        task_dict = horario[key].__dict__
        schedule_df.loc[key, 'Avg Time to Complete'] = task_dict['avgTime']
        schedule_df.loc[key,'Task Urgency'] = task_dict['urgency']
        schedule_df.loc[key,'Is it Hobby'] = key+' is a Hobby' if task_dict['isHobby'] else key+' is not a Hobby'
        schedule_df.loc[key,'Task Location'] = 'Uknown Location' if task_dict['location'] is None else task_dict['location']
        schedule_df.loc[key,'Task Recurrency'] = task_dict['recurrency']
    
    return schedule_df

# %% [markdown]
# Se añade la base de conocimiento al archivo, creada a partir del txt que se llena con la información de las tareas, y se llenan los diccionarios anteriores.

# %% [markdown]
# # Cálculo de la prioridad de cada tarea usando Logica Difusa

# %% [markdown]
# Creamos un sistema de lógica difusa con la variable prioridad y se le asigna a cada una de las tareas.

# %%
# Definir variables de entrada y salida
urgencia = ctrl.Antecedent(np.arange(1, 11, 1), 'urgencia')
prioridad = ctrl.Consequent(np.arange(0, 11, 1), 'prioridad')

def escribirPrioridad(prioridad):
    # Imprimir la prioridad asignada en forma de cadena de texto
    if prioridad <= 2.5:
        print("La prioridad de la tarea es baja")
    elif prioridad <= 7.5:
        print("La prioridad de la tarea es media")
    else:
        print("La prioridad de la tarea es alta")

# Definir los conjuntos difusos y las funciones de pertenencia correspondientes
urgencia['muy_baja'] = fuzz.trimf(urgencia.universe, [1, 1, 3])
urgencia['baja'] = fuzz.trimf(urgencia.universe, [1, 3, 5])
urgencia['media'] = fuzz.trimf(urgencia.universe, [3, 5, 7])
urgencia['alta'] = fuzz.trimf(urgencia.universe, [5, 7, 9])
urgencia['muy_alta'] = fuzz.trimf(urgencia.universe, [7, 10, 10])

prioridad['baja'] = fuzz.trimf(prioridad.universe, [0, 0, 5])
prioridad['media'] = fuzz.trimf(prioridad.universe, [0, 5, 10])
prioridad['alta'] = fuzz.trimf(prioridad.universe, [5, 10, 10])

# Definir las reglas difusas
regla1 = ctrl.Rule(urgencia['muy_baja'], prioridad['baja'])
regla2 = ctrl.Rule(urgencia['baja'], prioridad['baja'])
regla3 = ctrl.Rule(urgencia['media'], prioridad['media'])
regla4 = ctrl.Rule(urgencia['alta'], prioridad['alta'])
regla5 = ctrl.Rule(urgencia['muy_alta'], prioridad['alta'])

# Definir el sistema de control difuso
sistema = ctrl.ControlSystem([regla1, regla2, regla3, regla4, regla5])
asignar_prioridad = ctrl.ControlSystemSimulation(sistema)


for clave, valor in dictTasks.items():
    print("asigno Prioridad para: " +clave +", que tiene urgencia: "+ str(round(valor.urgency,2)))

    # Asignar un valor de urgencia para la tarea de desayunar
    asignar_prioridad.input['urgencia'] = valor.urgency

    # Calcular el resultado del sistema de control difuso
    asignar_prioridad.compute()

    # Obtener la salida (prioridad)
    prioridad_tarea = asignar_prioridad.output['prioridad']
    print('La prioridad de la tarea es:', round(prioridad_tarea,2))
    valor.prioridad= prioridad_tarea
    escribirPrioridad(valor.prioridad)


def recalculate_diffuse():
    for clave, valor in dictTasks.items():
        print("asigno Prioridad para: " +clave +", que tiene urgencia: "+ str(round(valor.urgency,2)))

        # Asignar un valor de urgencia para la tarea de desayunar
        asignar_prioridad.input['urgencia'] = valor.urgency

        # Calcular el resultado del sistema de control difuso
        asignar_prioridad.compute()

        # Obtener la salida (prioridad)
        prioridad_tarea = asignar_prioridad.output['prioridad']
        print('La prioridad de la tarea es:', round(prioridad_tarea,2))
        valor.prioridad= prioridad_tarea
        escribirPrioridad(valor.prioridad)
# Out:
# asigno Prioridad para: desayunar, que tiene urgencia: 5
# La prioridad de la tarea es: 5.0
# La prioridad de la tarea es media
# asigno Prioridad para: bañarse, que tiene urgencia: 2
# La prioridad de la tarea es: 1.94
# La prioridad de la tarea es baja
# asigno Prioridad para: hacer la tarea, que tiene urgencia: 7
# La prioridad de la tarea es: 8.33
# La prioridad de la tarea es alta
# asigno Prioridad para: almorzar, que tiene urgencia: 4
# La prioridad de la tarea es: 4.4
# La prioridad de la tarea es media
# asigno Prioridad para: hacer ejercicio, que tiene urgencia: 3
# La prioridad de la tarea es: 1.67
# La prioridad de la tarea es baja
# asigno Prioridad para: estudiar para el parcial, que tiene urgencia: 9
# La prioridad de la tarea es: 8.19
# La prioridad de la tarea es alta
# asigno Prioridad para: escuchar musica, que tiene urgencia: 1
# La prioridad de la tarea es: 1.67
# La prioridad de la tarea es baja
# asigno Prioridad para: leer documentacion, que tiene urgencia: 5
# La prioridad de la tarea es: 5.0
# La prioridad de la tarea es media
# asigno Prioridad para: sacar al perro, que tiene urgencia: 5
# La prioridad de la tarea es: 5.0
# La prioridad de la tarea es media
# asigno Prioridad para: hacer estiramientos, que tiene urgencia: 2
# La prioridad de la tarea es: 1.94
# La prioridad de la tarea es baja
# asigno Prioridad para: ver netflix, que tiene urgencia: 3
# La prioridad de la tarea es: 1.67
# La prioridad de la tarea es baja
# asigno Prioridad para: reunirse con amigos, que tiene urgencia: 4
# La prioridad de la tarea es: 4.4
# La prioridad de la tarea es media
# asigno Prioridad para: regar plantas, que tiene urgencia: 7
# La prioridad de la tarea es: 8.33
# La prioridad de la tarea es alta
# asigno Prioridad para: ordenar el cuarto, que tiene urgencia: 4
# La prioridad de la tarea es: 4.4
# La prioridad de la tarea es media
# asigno Prioridad para: jugar con el perro, que tiene urgencia: 6
# La prioridad de la tarea es: 5.6
# La prioridad de la tarea es media

# %% [markdown]
# Se describe cuales de las tareas que no están en el horario actual tienen mayor prioridad para que el usuario pueda priorizarlas lo mas pronto posible en caso de que tenga tiempo extra o deba cancelar otra actividad pendiente.

# %%
tareas_ordenadas_prioridad = []


# Crear un diccionario vacío para almacenar las tareas que no están en horario
nuevas_tareas = {}

# Iterar sobre las claves en dictTasks
for tarea in dictTasks.keys():
    
    # Comprobar si la tarea no está en horario
    if tarea not in horario:
        
        # Si no está en horario, agregarla al nuevo diccionario
        nuevas_tareas[tarea] = dictTasks[tarea]



print("En caso de no poder realizar alguna de las tareas en tu horario te recomendamos tomar alguna de alta prioridad,. \n a continuacion te las listamos en el orden recomendado: \n")

# Ordenar las tareas por prioridad (de mayor a menor)
tareas_ordenadas_prioridad = sorted(nuevas_tareas.values(), key=lambda x: x.prioridad, reverse=True)

# Recorrer las tareas ordenadas e imprimir su prioridad
for tarea in tareas_ordenadas_prioridad:
    print("-- " +tarea.name + ", con una prioridad de: " + str(round(tarea.prioridad, 2) ))


def ordenar_prioridad():
    # Iterar sobre las claves en dictTasks
    for tarea in dictTasks.keys():
        # Comprobar si la tarea no está en horario
        if tarea not in horario:
            # Si no está en horario, agregarla al nuevo diccionario
            nuevas_tareas[tarea] = dictTasks[tarea]
    print("En caso de no poder realizar alguna de las tareas en tu horario te recomendamos tomar alguna de alta prioridad,. \n a continuacion te las listamos en el orden recomendado: \n")

    # Ordenar las tareas por prioridad (de mayor a menor)
    tareas_ordenadas_prioridad = sorted(nuevas_tareas.values(), key=lambda x: x.prioridad, reverse=True)

    # Recorrer las tareas ordenadas e imprimir su prioridad
    for tarea in tareas_ordenadas_prioridad:
        print("-- " +tarea.name + ", con una prioridad de: " + str(round(tarea.prioridad, 2) ))
# Out:
# En caso de no poder realizar alguna de las tareas en tu horario te recomendamos tomar alguna de alta prioridad,.
#  a continuacion te las listamos en el orden recomendado:
#
# -- hacer la tarea, con una prioridad de: 8.33
# -- estudiar para el parcial, con una prioridad de: 8.19
# -- leer documentacion, con una prioridad de: 5.0
# -- almorzar, con una prioridad de: 4.4
# -- reunirse con amigos, con una prioridad de: 4.4
# -- ordenar el cuarto, con una prioridad de: 4.4
# -- bañarse, con una prioridad de: 1.94
# -- hacer estiramientos, con una prioridad de: 1.94
# -- hacer ejercicio, con una prioridad de: 1.67
# -- escuchar musica, con una prioridad de: 1.67
# -- ver netflix, con una prioridad de: 1.67

# %%
tareas_ordenadas_prioridad
# Out:
# [<__main__.TaskClass at 0x14729cc70>,
#  <__main__.TaskClass at 0x14729c9a0>,
#  <__main__.TaskClass at 0x14729d600>,
#  <__main__.TaskClass at 0x14729c5b0>,
#  <__main__.TaskClass at 0x14729d420>,
#  <__main__.TaskClass at 0x14729f9a0>,
#  <__main__.TaskClass at 0x14729d450>,
#  <__main__.TaskClass at 0x14729c5e0>,
#  <__main__.TaskClass at 0x14729d510>,
#  <__main__.TaskClass at 0x14729f010>,
#  <__main__.TaskClass at 0x14729c490>]

# %% [markdown]
# # Aprendizaje con Clusters de clasificación

# %% [markdown]
# En este código, se utilizan cuatro características para cada tarea: la duración promedio, el tiempo de inicio, la fecha límite y la urgencia. Se crea una matriz de características con estas características para todas las tareas en dictTasks. Luego, se aplica K-means con 3 clusters y se asigna cada tarea a su respectivo cluster.

# %%
# --- CREACION DE CLUSTERS DE TAREAS ---

#print(dictTasks)

# Crear la matriz de características para todas las tareas
features_matrix = []
for task_name, task in dictTasks.items():
    features = [task.taskType, task.avgTime, task.timeStart, task.urgency, task.deadline]
    features_matrix.append(features)
    
# Convertir la lista en una matriz NumPy
X = np.array(features_matrix)

print(X)

# Aplicar K-means con 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

# Asignar cada tarea a su respectivo cluster
for i, task_name in enumerate(dictTasks.keys()):
    dictTasks[task_name].cluster = kmeans.labels_[i]


# Obtener los centroides de cada cluster
centroids = kmeans.cluster_centers_

# Imprimir los centroides
print("Coordenadas de los centroides de cada cluster:")
print(centroids)
# Out:
# [[  1  40 480   5   1]
#  [  2  45 525   2   1]
#  [  4  60 590   7   5]
#  [  1  40 720   4   1]
#  [  5  50 630   3   4]
#  [  4  65 600   9   2]
#  [  7  20 660   1   7]
#  [  4  50 645   5   6]
#  [  3  30 530   5   2]
#  [  5  10 540   2   7]
#  [  7  60 655   3   8]
#  [  8  80 780   4   8]
#  [  6  15 605   7   5]
#  [  9  45 750   4   5]
#  [  3  30 790   6   7]]
# Coordenadas de los centroides de cada cluster:
# [[  5.28571429  45.71428571 626.42857143   5.           5.28571429]
#  [  5.25        48.75       760.           4.5          5.25      ]
#  [  2.75        31.25       518.75         3.5          2.75      ]]

# %% [markdown]
# Los centroides son los puntos centrales de cada cluster y proporcionan información sobre las características promedio de los datos que pertenecen a ese cluster. Al conocer las coordenadas de los centroides, puede inferir qué características tienen más influencia en la formación de cada cluster.
#
# Además, los centroides también se pueden utilizar para predecir a qué cluster pertenecerá una nueva tarea o dato que tenga características similares a las tareas ya agrupadas.

# %%
# Obtener los centroides de cada cluster
centroids = kmeans.cluster_centers_

# Imprimir los centroides
print("Coordenadas de los centroides de cada cluster:")
print(centroids)
# Out:
# Coordenadas de los centroides de cada cluster:
# [[  5.28571429  45.71428571 626.42857143   5.           5.28571429]
#  [  5.25        48.75       760.           4.5          5.25      ]
#  [  2.75        31.25       518.75         3.5          2.75      ]]

# %% [markdown]
# Observaremos que otra información relevante podemos imprimir:

# %%
# Obtener el número de tareas en cada grupo:
print("numero de tareas de cada grupo: ")
task_counts = pd.Series(kmeans.labels_).value_counts()
print(task_counts)

#Obtener las características promedio de cada grupo:
print("características promedio de cada grupo")
group_means = pd.DataFrame(X).groupby(kmeans.labels_).mean()
#print(group_means)
print(pd.DataFrame(X).groupby(kmeans.labels_).mean())

# Obtener las tareas pertenecientes a cada grupo:
print("Tareas en cada grupo:")
grouped_tasks = {}
for i, task_name in enumerate(dictTasks.keys()):
    group_id = kmeans.labels_[i]
    if group_id not in grouped_tasks:
        grouped_tasks[group_id] = []
    grouped_tasks[group_id].append(task_name)
    
for group_id, task_names in grouped_tasks.items():
    print(f"Tasks in group {group_id}:")
    print(task_names)
# Out:
# numero de tareas de cada grupo:
# 0    7
# 2    4
# 1    4
# dtype: int64
# características promedio de cada grupo
#           0          1           2    3         4
# 0  5.285714  45.714286  626.428571  5.0  5.285714
# 1  5.250000  48.750000  760.000000  4.5  5.250000
# 2  2.750000  31.250000  518.750000  3.5  2.750000
# Tareas en cada grupo:
# Tasks in group 2:
# ['desayunar', 'bañarse', 'sacar al perro', 'hacer estiramientos']
# Tasks in group 0:
# ['hacer la tarea', 'hacer ejercicio', 'estudiar para el parcial', 'escuchar musica', 'leer documentacion', 'ver netflix', 'regar plantas']
# Tasks in group 1:
# ['almorzar', 'reunirse con amigos', 'ordenar el cuarto', 'jugar con el perro']

# %% [markdown]
# cada punto representa una tarea, y cada color indica el grupo al que pertenece esa tarea, de acuerdo con el algoritmo de clustering.
#
# Cada grupo de tareas tiene características similares en términos de sus propiedades. Por ejemplo, si el algoritmo agrupó tareas con un tiempo promedio de realización alto y un plazo corto en un grupo, puede interpretarse que esas tareas requieren una atención inmediata y pueden ser consideradas como prioritarias

# %%
# Crear una lista de diccionarios a partir del diccionario de tareas
task_dicts = [task.__dict__ for task in dictTasks.values()]

# Crear un marco de datos de pandas a partir de la lista de diccionarios
df = pd.DataFrame(task_dicts)

#creo los colores
colors = ['red', 'green', 'blue']

# Seleccionar las columnas que se utilizarán para el clustering
columns = ['avgTime', 'deadline']
X = df[columns].to_numpy()

# Realizar el clustering con KMeans
kmeans = KMeans(n_clusters=3)
labels = kmeans.fit_predict(X)

# Graficamos los resultados
plt.scatter(X[:, 0], X[:, 1], c=[colors[i] for i in labels], s=50, )
plt.xlabel('Avg Time')
plt.ylabel('Deadline')

# Agregar una leyenda
legend_elements = [plt.Line2D([0], [0], marker='o', color=color, label=f'Cluster {i+1}', linestyle='') for i, color in enumerate(colors)]
plt.legend(handles=legend_elements)

plt.show()

# %%
# Crear una lista de diccionarios a partir del diccionario de tareas
task_dicts = [task.__dict__ for task in dictTasks.values()]

# Crear un marco de datos de pandas a partir de la lista de diccionarios
df = pd.DataFrame(task_dicts)

#creo los colores
colors = ['red', 'green', 'blue']

# Seleccionar las columnas que se utilizarán para el clustering
columns = ['deadline', 'urgency']
X = df[columns].to_numpy()

# Realizar el clustering con KMeans
kmeans = KMeans(n_clusters=3)
labels = kmeans.fit_predict(X)

# Graficamos los resultados
plt.scatter(X[:, 0], X[:, 1], c=[colors[i] for i in labels], s=50, )
plt.xlabel('deadline')
plt.ylabel('urgency')

# Agregar una leyenda
legend_elements = [plt.Line2D([0], [0], marker='o', color=color, label=f'Cluster {i+1}', linestyle='') for i, color in enumerate(colors)]
plt.legend(handles=legend_elements)

plt.show()

# %% [markdown]
# # Prueba de predicción de tiempo real vs tiempo precalculado que toman las tareas
#
# Para crear un modelo de regresión que prediga la duración real de una tarea, primero debemos cargar los datos de entrenamiento y prueba en Python.

# %%
# Cargamos los datos de entrenamiento y prueba en dataframes
train_data = pd.read_csv("agentTaskLog.csv")
test_data = pd.read_csv("agentTaskList.csv")

# %% [markdown]
# A continuación, debemos limpiar y preprocesar los datos para asegurarnos de que sean adecuados para el modelo. Esto incluye eliminar cualquier dato innecesario o faltante, convertir los datos categóricos en valores numéricos y normalizar los datos para que estén en la misma escala.

# %%
# Asegurarse de que las columnas a eliminar estén presentes en ambos conjuntos de datos
cols_to_drop = ["TaskID", "Name", "Parent", "Location", "Involves", "BestOn"]
train_data = train_data.reindex(columns=train_data.columns.tolist() + cols_to_drop)
test_data = test_data.reindex(columns=test_data.columns.tolist() + cols_to_drop)

# Eliminar columnas innecesarias para la predicción
train_data = train_data.drop(cols_to_drop, axis=1)
test_data = test_data.drop(cols_to_drop, axis=1)

# Eliminar columnas adicionales en el conjunto de datos de prueba que no están presentes en el conjunto de datos de entrenamiento
cols_to_drop_extra = ["timeEnds", "dayOfWeek"]
train_data = train_data.drop(cols_to_drop_extra, axis=1)

# Convertir las columnas categóricas en valores numéricos usando one-hot encoding
train_data = pd.get_dummies(train_data, columns=[ "IsHobby" ])
test_data = pd.get_dummies(test_data, columns=[ "IsHobby" ])

# Normalizar los datos usando la biblioteca Scikit-learn
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
train_data
# Out:
#     TaskType  AvgTime  Urgency  TimeStart  Deadline  Recurrency  \
# 0          1       40        5        480         1           7
# 1          3       50        6        530         1           7
# 2          4       65        9        600         2           2
# 3          1       40        4        720         1           7
# 4          1       40        5        485         1           7
# 5          2       45        2        525         1           6
# 6          7       20        1        600         7           2
# 7          2       60        4        640         4           3
# 8          1       55        3        730         1           7
# 9          4       60        8        800         3           4
# 10         2       30        6        500         2           5
# 11         4       55        8        550         4           4
# 12         8       80        4        615         5           2
# 13         1       55        2        720         4           1
# 14         8       65        8        790         6           2
# 15         6       30        2        460         2           3
# 16         1       45        5        505         1           7
# 17         4       50        8        620         5           4
# 18         3       40        5        685         2           3
# 19         1       55        7        800         1           7
# 20         8       40        1        850         7           2
#
#     IsHobby_False  IsHobby_True
# 0               1             0
# 1               1             0
# 2               1             0
# 3               1             0
# 4               1             0
# 5               1             0
# 6               0             1
# 7               1             0
# 8               1             0
# 9               1             0
# 10              1             0
# 11              1             0
# 12              0             1
# 13              1             0
# 14              1             0
# 15              1             0
# 16              1             0
# 17              1             0
# 18              1             0
# 19              1             0
# 20              0             1

# %%
test_data
# Out:
#     TaskType  AvgTime  Urgency  TimeStart  Deadline  Recurrency  \
# 0          1       40        5        480         1           7
# 1          2       45        2        525         1           6
# 2          3       30        5        530         2           7
# 3          4       60        7        590         5           5
# 4          4       65        9        600         2           2
# 5          5       10        2        540         7           4
# 6          6       15        7        605         5           2
# 7          1       40        4        720         1           7
# 8          5       50        3        630         4           5
# 9          7       20        1        660         7           2
# 10         4       50        5        645         6           4
# 11         7       60        3        655         8           3
# 12         8       80        4        780         8           2
# 13         9       45        4        750         5           5
# 14         3       30        6        790         7           6
#
#     IsHobby_False  IsHobby_True
# 0               1             0
# 1               1             0
# 2               1             0
# 3               1             0
# 4               1             0
# 5               1             0
# 6               1             0
# 7               1             0
# 8               1             0
# 9               0             1
# 10              1             0
# 11              0             1
# 12              0             1
# 13              1             0
# 14              1             0

# %%
train_data[["AvgTime", "Urgency", "Recurrency", "Deadline"]] = scaler.fit_transform(train_data[["AvgTime", "Urgency", "Recurrency", "Deadline"]])
test_data[["AvgTime", "Urgency", "Recurrency", "Deadline"]] = scaler.transform(test_data[["AvgTime", "Urgency", "Recurrency", "Deadline"]])

# %% [markdown]
# Una vez que los datos estén preparados, podemos entrenar el modelo de regresión. Usamos la biblioteca Scikit-learn para crear y ajustar el modelo a los datos de entrenamiento.

# %%
# Creamos el modelo de regresión lineal
model = LinearRegression()

# Seleccionamos las columnas de características y la columna objetivo en los datos de entrenamiento
X_train = train_data.drop(["AvgTime"], axis=1)
y_train = train_data["AvgTime"]

# Ajustamos el modelo a los datos de entrenamiento
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Finalmente, podemos utilizar el modelo entrenado para hacer predicciones sobre los datos de prueba. Podemos seleccionar las mismas columnas de características en los datos de prueba y usar el método predict() del modelo para hacer predicciones.

# %%
# Seleccionamos las columnas de características en los datos de prueba
X_test = test_data.drop(["AvgTime"], axis=1)

# Hacemos predicciones sobre los datos de prueba
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([-0.5733763 , -0.9763492 , -0.69200461, -0.32320986,  1.40902181,
#        -1.89137162,  0.26601077, -0.13232488, -0.95853833, -0.58268628,
#        -0.65450219, -0.538609  ,  0.22297996, -0.69064389, -0.59758016])

# %% [markdown]
# Ahora tendremos un array y_pred con las predicciones para la duración de cada tarea en la base de prueba. Para evaluar la calidad del modelo, podemos comparar las predicciones con los valores reales de duración en la base de prueba.
#
# Una métrica comúnmente usada para evaluar modelos de regresión es el coeficiente de determinación R2. Este coeficiente mide la proporción de la varianza en los datos que es explicada por el modelo. Un valor de R2 cercano a 1 indica que el modelo ajusta bien a los datos, mientras que un valor cercano a 0 indica que el modelo no explica bien la varianza en los datos.
#
# Podemos calcular el valor de R2 para nuestro modelo usando la función r2_score de la biblioteca scikit-learn:

# %%
y_true = test_data["AvgTime"]

# comparar los valores reales normalizados con los valores predichos
r2 = r2_score(y_true, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.23049686074912712

# %% [markdown]
# El valor del R2 score es un número entre 0 y 1 que indica cuánta varianza en la variable objetivo (en este caso, la columna "AvgTime" en los datos de prueba) se puede explicar por las variables predictoras (las otras columnas en los datos). Cuanto mayor sea el R2 score, mejor será la capacidad del modelo para predecir los valores de la variable objetivo. En este caso, el R2 score obtenido es de 0.23, lo que sugiere que el modelo no explica muy bien la varianza en los datos y tiene un desempeño limitado en la predicción de la variable objetivo.

# %% [markdown]
# También podemos visualizar los resultados del modelo usando un gráfico de dispersión. En este gráfico, podemos representar en el eje x los valores reales de duración y en el eje y las predicciones del modelo. Idealmente, los puntos deberían estar alineados con la línea diagonal, lo que indicaría que las predicciones coinciden con los valores reales.

# %%
plt.scatter(y_true, y_pred)
plt.plot([0, 10], [0, 10], '--k')
plt.xlabel('Duración real')
plt.ylabel('Duración predicha')
plt.show()

# %% [markdown]
# # Optimizando el cálculo de la urgencia

# %%
# Recálculo de la urgencia.

def findUrgencyGroup(agentTaskLog: pd.DataFrame) -> pd.DataFrame:
    """Metodo para hallar tipo de urgencia mediante cluster KMeans"""
    
    def encodeCategorical(agentTaskLog: pd.DataFrame):
        dfEncoded = agentTaskLog.copy()
        #One hot encoding o label encoding a columns str del set de datos
        dfEncoded["EncodedLocation"] = LabelEncoder().fit_transform(dfEncoded["Location"])
        dfEncoded["EncodedIsHobby"] = dfEncoded["IsHobby"].apply(lambda x: 1 if x else 0)
        dfEncoded["EncodedBestOn"] = LabelEncoder().fit_transform(dfEncoded["BestOn"])
        return dfEncoded
    
    
    clustersDf = agentTaskLog.copy() #copio dataframe de entrada para no sobreescribirlo
    clustersDf = encodeCategorical(clustersDf)
    X = clustersDf[["AvgTime","Deadline","EncodedLocation","EncodedIsHobby"]]
    
    kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
    clustersDf["Group"] = kmeans.labels_
    
    print(f"Silhouette score of KMeans: {silhouette_score(X,kmeans.labels_)}")
    return clustersDf[["AvgTime","Deadline","EncodedLocation","EncodedIsHobby","Urgency","Group"]]


def predictTaskUrgency(clusters_df:pd.DataFrame) -> pd.DataFrame:
    def testSVM(X,Y) -> dict:
        svr = SVR()
        svr.fit(X,Y) #entrenamiento del modelo
        svrPrediction = svr.predict(X)
        r2 = r2_score(Y, svrPrediction) #r2 del modelo
        mseMetric = mse(Y,svrPrediction)
        return {
            "r2":r2,
            "mse":mseMetric,
            "prediction":svrPrediction
        }


    def testLinearRegression(X,Y) -> dict:
        linearRegression = LinearRegression()
        linearRegression.fit(X,Y) #entrenamiento del modelo
        lrPrediction = linearRegression.predict(X)
        r2 = r2_score(Y,lrPrediction)
        mseMetric = mse(Y,lrPrediction)
        return {
            "r2":r2,
            "mse":mseMetric,
            "prediction":lrPrediction
        }
    
    def appendToDataFrameMetrics(urgencyDf:pd.DataFrame, mse:float, r2:float) -> pd.DataFrame:
        metricsDf = urgencyDf.copy()
        metricsDf["r2Metric"] = r2
        metricsDf["mseMetric"] = mse
        return metricsDf    
    
    
    urgencyDf = clusters_df.copy() #copio dataframe de entrada para no sobreescribirlo
    dataScaler = StandardScaler()
    trainData = pd.DataFrame( #normalizar los datos de entrada
        columns=clusters_df.columns,
        data = dataScaler.fit_transform(urgencyDf)
    )
    
    X = trainData.drop(columns = ["Urgency"])
    Y = trainData["Urgency"]
    lrResults = testLinearRegression(X,Y)
    svmResults = testSVM(X,Y)
    XLr = X
    XLr["Urgency"] = lrResults["prediction"]
    XLr = pd.DataFrame(
        columns= urgencyDf.columns,
        data = dataScaler.inverse_transform(XLr)
        )
    XSvm = X
    XSvm["Urgency"] = svmResults["prediction"]
    XSvm = pd.DataFrame(
        columns= urgencyDf.columns,
        data = dataScaler.inverse_transform(XSvm) 
    )

    #si el r2 de ambos es igual buscar el modelo que menos tenga mse
    if lrResults["r2"] == svmResults["r2"]: 
        if lrResults["mse"] < svmResults["mse"]: #retorno prediccion del SVM
            urgencyDf = appendToDataFrameMetrics(XSvm,
                                                 svmResults["mse"],
                                                 svmResults["r2"])
            return urgencyDf
        #retorno prediccion de la regresion lineal
        urgencyDf = appendToDataFrameMetrics(XLr,
                                            lrResults["mse"],
                                            lrResults["r2"])
        return urgencyDf
    elif lrResults["r2"] < svmResults["r2"]:
        urgencyDf = appendToDataFrameMetrics(XSvm,
                                            svmResults["mse"],
                                            svmResults["r2"])
        return urgencyDf
    urgencyDf = appendToDataFrameMetrics(XLr,
                                        lrResults["mse"],
                                        lrResults["r2"])
    return urgencyDf

df = pd.read_csv("./agentTaskLog.csv")
clustersDf = findUrgencyGroup(df)
urgencyDf = predictTaskUrgency(clustersDf)

urgencyDf
# Out:
# Silhouette score of KMeans: 0.535974272590046
#     AvgTime  Deadline  EncodedLocation  EncodedIsHobby   Urgency     Group  \
# 0      40.0       1.0              1.0             0.0  7.451379  0.445814
# 1      50.0       1.0              1.0             0.0  2.589655  0.789028
# 2      65.0       2.0              0.0             0.0  2.589655  1.069844
# 3      40.0       1.0              4.0             0.0  7.451379  0.240239
# 4      40.0       1.0              1.0             0.0  7.451379  0.445814
# 5      45.0       1.0              1.0             0.0  7.451379  0.463092
# 6      20.0       7.0              1.0             1.0  7.451379 -0.276924
# 7      60.0       4.0              1.0             0.0  2.589655  1.077328
# 8      55.0       1.0              4.0             0.0  2.589655  0.134126
# 9      60.0       3.0              1.0             0.0  2.589655  1.063043
# 10     30.0       2.0              1.0             0.0  7.451379  0.427899
# 11     55.0       4.0              0.0             0.0  2.589655  1.062658
# 12     80.0       5.0              2.0             1.0  2.589655  0.340266
# 13     55.0       4.0              4.0             0.0  2.589655  0.221726
# 14     65.0       6.0              3.0             0.0  2.589655  0.678555
# 15     30.0       2.0              1.0             0.0  7.451379  0.427899
# 16     45.0       1.0              1.0             0.0  7.451379  0.463092
# 17     50.0       5.0              1.0             0.0  2.589655  0.975354
# 18     40.0       2.0              1.0             0.0  7.451379  0.470272
# 19     55.0       1.0              1.0             0.0  2.589655  0.857114
# 20     40.0       7.0              1.0             1.0  7.451379 -0.276924
#
#     r2Metric  mseMetric
# 0   0.664179   0.335821
# 1   0.664179   0.335821
# 2   0.664179   0.335821
# 3   0.664179   0.335821
# 4   0.664179   0.335821
# 5   0.664179   0.335821
# 6   0.664179   0.335821
# 7   0.664179   0.335821
# 8   0.664179   0.335821
# 9   0.664179   0.335821
# 10  0.664179   0.335821
# 11  0.664179   0.335821
# 12  0.664179   0.335821
# 13  0.664179   0.335821
# 14  0.664179   0.335821
# 15  0.664179   0.335821
# 16  0.664179   0.335821
# 17  0.664179   0.335821
# 18  0.664179   0.335821
# 19  0.664179   0.335821
# 20  0.664179   0.335821

# %%
# Definir variables de entrada y salida
urgencia = ctrl.Antecedent(np.arange(1, 11, 1), 'urgencia')
prioridad = ctrl.Consequent(np.arange(0, 11, 1), 'prioridad')

# Definir los conjuntos difusos y las funciones de pertenencia correspondientes
urgencia['muy_baja'] = fuzz.trimf(urgencia.universe, [1, 1, 3])
urgencia['baja'] = fuzz.trimf(urgencia.universe, [1, 3, 5])
urgencia['media'] = fuzz.trimf(urgencia.universe, [3, 5, 7])
urgencia['alta'] = fuzz.trimf(urgencia.universe, [5, 7, 9])
urgencia['muy_alta'] = fuzz.trimf(urgencia.universe, [7, 10, 10])

prioridad['baja'] = fuzz.trimf(prioridad.universe, [0, 0, 5])
prioridad['media'] = fuzz.trimf(prioridad.universe, [0, 5, 10])
prioridad['alta'] = fuzz.trimf(prioridad.universe, [5, 10, 10])

# Definir las reglas difusas
regla1 = ctrl.Rule(urgencia['muy_baja'], prioridad['baja'])
regla2 = ctrl.Rule(urgencia['baja'], prioridad['baja'])
regla3 = ctrl.Rule(urgencia['media'], prioridad['media'])
regla4 = ctrl.Rule(urgencia['alta'], prioridad['alta'])
regla5 = ctrl.Rule(urgencia['muy_alta'], prioridad['alta'])

# Definir el sistema de control difuso
sistema = ctrl.ControlSystem([regla1, regla2, regla3, regla4, regla5])
asignar_prioridad = ctrl.ControlSystemSimulation(sistema)

def escribirPrioridad(prioridad):
    # Imprimir la prioridad asignada en forma de cadena de texto
    if prioridad_tarea <= 2.5:
        print("La prioridad de la tarea es baja")
    elif prioridad_tarea <= 7.5:
        print("La prioridad de la tarea es media")
    else:
        print("La prioridad de la tarea es alta")

priorityList = []
for i,urgency in enumerate(urgencyDf["Urgency"]):
    asignar_prioridad.input['urgencia'] = urgency
    asignar_prioridad.compute()
    prioridad_tarea = asignar_prioridad.output['prioridad']
    priorityList.append(prioridad_tarea)
urgencyDf["Priority"] = priorityList

# %%
urgencyDf
# Out:
#     AvgTime  Deadline  EncodedLocation  EncodedIsHobby   Urgency     Group  \
# 0      40.0       1.0              1.0             0.0  7.451379  0.445814
# 1      50.0       1.0              1.0             0.0  2.589655  0.789028
# 2      65.0       2.0              0.0             0.0  2.589655  1.069844
# 3      40.0       1.0              4.0             0.0  7.451379  0.240239
# 4      40.0       1.0              1.0             0.0  7.451379  0.445814
# 5      45.0       1.0              1.0             0.0  7.451379  0.463092
# 6      20.0       7.0              1.0             1.0  7.451379 -0.276924
# 7      60.0       4.0              1.0             0.0  2.589655  1.077328
# 8      55.0       1.0              4.0             0.0  2.589655  0.134126
# 9      60.0       3.0              1.0             0.0  2.589655  1.063043
# 10     30.0       2.0              1.0             0.0  7.451379  0.427899
# 11     55.0       4.0              0.0             0.0  2.589655  1.062658
# 12     80.0       5.0              2.0             1.0  2.589655  0.340266
# 13     55.0       4.0              4.0             0.0  2.589655  0.221726
# 14     65.0       6.0              3.0             0.0  2.589655  0.678555
# 15     30.0       2.0              1.0             0.0  7.451379  0.427899
# 16     45.0       1.0              1.0             0.0  7.451379  0.463092
# 17     50.0       5.0              1.0             0.0  2.589655  0.975354
# 18     40.0       2.0              1.0             0.0  7.451379  0.470272
# 19     55.0       1.0              1.0             0.0  2.589655  0.857114
# 20     40.0       7.0              1.0             1.0  7.451379 -0.276924
#
#     r2Metric  mseMetric  Priority
# 0   0.664179   0.335821  8.264072
# 1   0.664179   0.335821  1.724882
# 2   0.664179   0.335821  1.724882
# 3   0.664179   0.335821  8.264072
# 4   0.664179   0.335821  8.264072
# 5   0.664179   0.335821  8.264072
# 6   0.664179   0.335821  8.264072
# 7   0.664179   0.335821  1.724882
# 8   0.664179   0.335821  1.724882
# 9   0.664179   0.335821  1.724882
# 10  0.664179   0.335821  8.264072
# 11  0.664179   0.335821  1.724882
# 12  0.664179   0.335821  1.724882
# 13  0.664179   0.335821  1.724882
# 14  0.664179   0.335821  1.724882
# 15  0.664179   0.335821  8.264072
# 16  0.664179   0.335821  8.264072
# 17  0.664179   0.335821  1.724882
# 18  0.664179   0.335821  8.264072
# 19  0.664179   0.335821  1.724882
# 20  0.664179   0.335821  8.264072

# %% [markdown]
# ## Informacion de habitos de uso de redes sociales

# %% [markdown]
# Queremos monitorear el uso de redes sociales del usuario para informarle que tanto tiempo esta gastando en esta actividad y a que hora hace uso de ella con mayor frecuencia.

# %%
# Aurenticacion con API twitter v2.0
"""
# Autenticación con las credenciales de la API de Twitter
consumer_key = 'SViGIvJnGdabUq1jdfu01iwDF'
consumer_secret = 'k0d9KUzYVqTklHkQm2Cpc5uVN1BDRFckYeGl4qgBOgnKmcKxDf'
access_token = '1580914511254589441-bRfWqmuKGswDqqdHK88X0zQ55xMIN7'
access_token_secret = 'VNoA640kEEiFZ1UCWfIIuh0TRuDIDWmIly5uwORhg4eD2'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Inicializar la API de Tweepy
api = tweepy.API(auth)

# Obtener los últimos 200 tweets del usuario especificado
tweets = api.user_timeline(screen_name='shakira', count=200)
#tweets = api.get_user_timeline(screen_name='shakira', count=200)

# Crear un dataframe temporal para almacenar los datos de los tweets!!
df = pd.DataFrame()

# Iteramos a través de los tweets y agregar los datos relevantes al dataframe
for tweet in tweets:
    df = df.append(pd.Series([tweet.status_id, tweet.created_at, tweet.text]), ignore_index=True)

# Hay que convertir la columna de fechas a formato de hora
df['created_at'] = pd.to_datetime(df['created_at']).dt.time

# Agregamos una columna con la hora del tweet ???
df['hour'] = [time.hour for time in df['created_at']]

# Contar cuántos tweets se publicaron en cada hora del día por el user
counts = df.groupby(['hour']).count()

# Encontrar la hora con la mayoría de tweets
most_common_hour = counts['text'].idxmax()

# Imprimir la hora con más tweets ! -> habito
print(f"La hora en que se publican más tweets es {most_common_hour}:00")
print(f"recuerde usar las redes sociales con moderación para hacer un uso eficiente de su tiempo libre!")

"""

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Lectura de datos de csv ya que la API es paga
ssl._create_default_https_context = ssl._create_unverified_context

url = 'https://raw.githubusercontent.com/JoaquinAmatRodrigo/Estadistica-con-R/master/datos/'
#url = 'https://raw.githubusercontent.com/JoaquinAmatRodrigo/Estadistica-con-R/master/datos/datos_tweets_%40elonmusk.csv'
tweets   = pd.read_csv(url + "datos_tweets_@elonmusk.csv", nrows=300)
print('Número de tweets @elonmusk: ' + str(tweets.shape[0]))


# Lectura de datos de csv ya que la API es paga
ssl._create_default_https_context = ssl._create_unverified_context

url = 'https://raw.githubusercontent.com/JoaquinAmatRodrigo/Estadistica-con-R/master/datos/'
tweets = pd.read_csv(url + "datos_tweets_@elonmusk.csv")
print('Número de tweets @elonmusk: ' + str(tweets.shape[0]))

# Crear un dataframe temporal para almacenar los datos de los tweets!!
df = pd.DataFrame(columns=['status_id', 'created_at', 'text'])

# Iteramos a través de las filas del dataframe y agregar los datos relevantes al dataframe temporal
for i, row in tweets.iterrows():
    df = df.append({'status_id': row['status_id'], 
                    'created_at': row['created_at'], 
                    'text': row['text']}, ignore_index=True)

# Hay que convertir la columna de fechas a formato de hora
df['created_at'] = pd.to_datetime(df['created_at']).dt.time

# Agregamos una columna con la hora del tweet ???
df['hour'] = [time.hour for time in df['created_at']]

# Contar cuántos tweets se publicaron en cada hora del día por el user
hour_count = df.groupby(['hour']).count()

print(hour_count)

# Encontrar la hora con la mayoría de tweets
most_common_hour = hour_count['text'].idxmax()

# Imprimir la hora con más tweets ! -> habito
print(f"La hora en que se publican más tweets es {most_common_hour}:00")
print(f"recuerde usar las redes sociales con moderación para hacer un uso eficiente de su tiempo libre!")
# Out:
# Número de tweets @elonmusk: 300
# Número de tweets @elonmusk: 2678
#       status_id  created_at  text
# hour
# 0           150         150   150
# 1           182         182   182
# 2           111         111   111
# 3            84          84    84
# 4           105         105   105
# 5           102         102   102
# 6            99          99    99
# 7            85          85    85
# 8            76          76    76
# 9            57          57    57
# 10           38          38    38
# 11           13          13    13
# 12           25          25    25
# 13           18          18    18
# 14           81          81    81
# 15          152         152   152
# 16          171         171   171
# 17          179         179   179
# 18          148         148   148
# 19          161         161   161
# 20          174         174   174
# 21          167         167   167
# 22          166         166   166
# 23          134         134   134
# La hora en que se publican más tweets es 1:00
# recuerde usar las redes sociales con moderación para hacer un uso eficiente de su tiempo libre!

# %% [markdown]
# ## Interfaz

# %%
def procesamiento_audio(csv_file, audio_file_taskType, audio_file_name, audio_file_avgTime, audio_file_urgency, audio_file_timeStart , audio_file_deadline, audio_file_location, audio_file_isHobby, audio_file_recurrency, audio_file_bestOn , audio_file_involves ):
    # Procesamiento de los audios.
    r = sr.Recognizer()

    # PARSING TASK NAME

    with sr.AudioFile(audio_file_name) as source:
        audio = r.record(source)

    taskName = r.recognize_google(audio, language="es-ES")

    print("Nombre de la tarea: "+taskName)

    # PARRSING DE TASKTYPE

    with sr.AudioFile(audio_file_taskType) as source:
        audio = r.record(source)

    taskType = r.recognize_google(audio, language="es-ES")
    print(taskType)

    # Revisamos que los datos capturados sean un digito numerico:
    if taskType.isdigit():
        taskType = int(taskType)
    else:
        print("La cadena no contiene solo números")

    print(f"--> El ID de el tipo de tarea es {taskType}")


    # PARSING DE AVGTIME

    with sr.AudioFile(audio_file_avgTime) as source:
        audio = r.record(source)

    taskAvgTime = r.recognize_google(audio, language="es-ES")
    print(taskAvgTime)

    # Revisamos que los datos capturados sean un digito numerico:
    if taskAvgTime.isdigit():
        taskAvgTime = int(taskAvgTime)
    else:
        print("La cadena no contiene solo números")

    print(f"--> El tiempo promedio es {taskAvgTime} minutos")


    # PARSING DE URGENCY

    with sr.AudioFile(audio_file_urgency) as source:
        audio = r.record(source)

    taskUrgency = r.recognize_google(audio, language="es-ES")
    print(taskUrgency)

    # Revisamos que los datos capturados sean un digito numerico:
    if taskUrgency.isdigit():
        taskUrgency = int(taskUrgency)
    else:
        print("La cadena no contiene solo números")

    print(f"--> La urgencia es {taskUrgency}")



    # PARSING DE TIME START

    with sr.AudioFile(audio_file_timeStart) as source:
        audio = r.record(source)

    tasktimeStart = r.recognize_google(audio, language="es-ES")
    print(tasktimeStart)

    # Conversion de la hora

    # Convertir el texto en una hora legible por datetime.strptime()
    dt_str = dateparser.parse(tasktimeStart).strftime("%H:%M")

    # Convertir la hora en formato string a un objeto datetime
    dt = datetime.datetime.strptime(dt_str, "%H:%M")


    # Calcular los minutos transcurridos desde que inició el día
    minutes = dt.hour * 60 + dt.minute

    print(f"--> La hora de inicio es {dt.strftime('%H:%M:%S')}, que equivale a {minutes} minutos desde que inició el día.")


    # PARSING DE DEADLINE

    with sr.AudioFile(audio_file_deadline) as source:
        audio = r.record(source)

    taskDeadline = r.recognize_google(audio, language="es-ES")
    print(taskDeadline)

    # Revisamos que los datos capturados sean un digito numerico:
    if taskDeadline.isdigit():
        taskDeadline = int(taskDeadline)
    else:
        print("La cadena no contiene solo números")

    print(f"--> La deadline es {taskDeadline}")


    # PARSING DE LOCATION

    with sr.AudioFile(audio_file_location) as source:
        audio = r.record(source)

    taskLocation = r.recognize_google(audio, language="es-ES")
    print(taskLocation)

    print(f"--> La ubicación de la tarea es en {taskDeadline}")


    # PARSING DE IS HOBBY

    with sr.AudioFile(audio_file_isHobby) as source:
        audio = r.record(source)

    taskIsHobby = r.recognize_google(audio, language="es-ES")
    print(taskIsHobby)

    # Conversión a booleano en formato inglés
    if taskIsHobby.lower() == "verdadero":
        isHobby = True
    elif taskIsHobby.lower() == "falso":
        isHobby = False
    else:
        isHobby = False

    print(f"--> La tarea es hobby? {taskIsHobby}")


    # PARSING DE RECURRENCY

    with sr.AudioFile(audio_file_recurrency) as source:
        audio = r.record(source)

    taskRecurrency = r.recognize_google(audio, language="es-ES")
    print(taskRecurrency)

    # Revisamos que los datos capturados sean un digito numerico:
    if taskRecurrency.isdigit():
        taskRecurrency = int(taskRecurrency)
    else:
        print("La cadena no contiene solo números")

    print(f"--> La recurrencia es {taskRecurrency}")


    # PARSING DE BEST ON 

    with sr.AudioFile(audio_file_bestOn) as source:
        audio = r.record(source)

    taskBestOn = r.recognize_google(audio, language="es-ES")
    print(taskBestOn)

    print(f"--> El mejor momento para realizar la tarea es:  {taskRecurrency}")



    # PARSING DE INVOLVES

    with sr.AudioFile(audio_file_involves) as source:
        audio = r.record(source)

    taskInvolves = r.recognize_google(audio, language="es-ES")
    print(taskInvolves)

    print(f"--> La tarea involucra a alguien mas? {taskInvolves}")

    # --- reiniciamos el file para solo añadir el nuevo registro
    #file_path = "./audio_files/audio_tasks_ui.csv"
    file_path = csv_file

    # Lee los encabezados del archivo CSV
    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)  # Obtiene los encabezados

    # Sobrescribe el archivo CSV con los encabezados
    with open(file_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(headers)

    # El archivo CSV ahora está vacío, excepto por la primera línea con los encabezados
    # ---

    # Abre el archivo CSV en modo de lectura
    with open(file_path, mode='r') as archivo_csv:
        # Crea un objeto csv.reader
        reader = csv.reader(archivo_csv)
        # Cuenta el número de líneas en el archivo CSV (restando la primera línea de encabezados)
        num_lines = len(list(reader))

    # Abre el archivo CSV en modo de escritura
    with open(file_path, mode='a', newline='') as archivo_csv:
        # Asigna el valor de var1 como el número de líneas en el archivo CSV
        taskID = num_lines
        # Crea un objeto csv.writer
        writer = csv.writer(archivo_csv)
        # Escribe la línea en el orden que necesitamos para que coincida con el formato preestablecido
        writer.writerow([taskID, taskType, taskName , taskAvgTime, taskUrgency, tasktimeStart, taskDeadline, taskLocation, taskIsHobby, taskRecurrency, taskBestOn, taskInvolves])

# %%
import pandas as pd

def ordenar_tareas_en_arbol(tasks_unordered, tasks_ordered):
    df = pd.read_csv(tasks_unordered)
    df = df.sort_values(by=["TimeStart"])

    parents = {}

    for i, row in df.iterrows():
        closest_distance = float("inf")
        closest_parent = None
        for j in range(i):
            previous_end_time = int(df.iloc[j]["TimeStart"]) + int(df.iloc[j]["AvgTime"])
            if previous_end_time <= int(row["TimeStart"]) and (int(row["TimeStart"]) - previous_end_time) < closest_distance:
                closest_distance = int(row["TimeStart"]) - previous_end_time
                closest_parent = int(df.iloc[j]["TaskID"])
        if closest_parent is not None:
            parents[int(row["TaskID"])] = int(closest_parent)

    df["Parent"] = df["TaskID"].map(parents)
    df.to_csv(tasks_ordered, index=False)

# %%
import pandas as pd

def agregar_por_audio(audio_file_taskType, audio_file_name, audio_file_avgTime, audio_file_urgency, audio_file_timeStart , audio_file_deadline, audio_file_location, audio_file_isHobby, audio_file_recurrency, audio_file_bestOn , audio_file_involves):
    csv_file = "./UI/tareas_audio.csv"
    procesamiento_audio(csv_file, audio_file_taskType, audio_file_name, audio_file_avgTime, audio_file_urgency, audio_file_timeStart , audio_file_deadline, audio_file_location, audio_file_isHobby, audio_file_recurrency, audio_file_bestOn , audio_file_involves)
    
    # Cargar los datos del primer archivo CSV
    df1 = pd.read_csv('./UI/tareas.csv')
    # Cargar los datos del segundo archivo CSV
    df2 = pd.read_csv('./UI/tareas_audio.csv')

    # Concatenar los dos DataFrames sin reiniciar los índices
    df_combinado = pd.concat([df1, df2], ignore_index=True)

    # Ordenar el DataFrame combinado por la columna 'TaskID' en orden ascendente
    df_combinado.sort_values(by='TaskID', inplace=True)

    # Restablecer los índices
    df_combinado.reset_index(drop=True, inplace=True)

    # Generar una nueva columna 'NuevoTaskID' con valores numéricos del 1 al número total de filas
    df_combinado['NuevoTaskID'] = range(1, len(df_combinado) + 1)
    # Reemplazar la columna 'TaskID' con la nueva columna 'NuevoTaskID'
    df_combinado['TaskID'] = df_combinado['NuevoTaskID']

    # Eliminar la columna 'NuevoTaskID'
    df_combinado.drop('NuevoTaskID', axis=1, inplace=True)
    # Guardar los cambios en un nuevo archivo CSV
    df_combinado.to_csv('./UI/tareas_all.csv', index=False)

    recalcular_datos()
        
   

def agregar_por_texto(tarea):
    
    csv_file = './UI/tareas_all.csv'  # Nombre del archivo CSV existente

    # Leer el archivo CSV existente y contar el número de líneas
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        line_count = sum(1 for _ in reader)

    # Asignar el nuevo ID basado en el número de líneas
    tarea['TaskID'] = str(line_count)
    #tarea['recurrency'] = int(tarea['recurrency'])

    """
    name = tarea['Name']
    task_type = tarea['TaskType']
    avg_time = tarea['AvgTime']
    urgency = tarea['Urgency']
    time_start = tarea['TimeStart']
    deadline = tarea['Deadline']
    location = tarea['Location']
    is_hobby = tarea['IsHobby']
    recurrency = tarea['Recurrency']
    best_on = tarea['BestOn']
    involves = tarea['Involves']
    """

    # Conversion al formato de minutos
    #tarea['TimeStart'] = convertir_hora_a_minutos(tarea['TimeStart'])


    # Añadir los datos de la nueva tarea al archivo CSV
    with open(csv_file, 'a', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=tarea.keys())

        # Escribir los datos de la nueva tarea
        writer.writerow(tarea)

    #recalcular_datos()

def reschedule_activities(csv_file):
    reorganizar_csv_por_task_id(csv_file)
    #inicializando el agente para el usuario
    myAgent = ScheduleAgent(name=username,
                            age=age,
                            gender=gender,
                            taskList=pd.read_csv(csv_file),
                            comments = "")
    crearHorario()
    classifyTasks(myAgent.rootNode)


def recalcular_datos():
    print("Cuando se eliminan o agregan tareas")

    # Primero ordenamos las tareas -> que tengan parents
    ordenar_tareas_en_arbol("./UI/tareas_all.csv", "./UI/tareas_orden.csv")
    # Recalculamos el horario
    reschedule_activities("./UI/tareas_orden.csv")
    # Recalculamos la prioridad
    recalculate_diffuse()
    ordenar_prioridad()

# %% [markdown]
# ## UI Interface programming

# %%
import PySimpleGUI as sg
sg.theme('Light Blue 6')

tareas =[]
data_horario = []
datos_difusa = []

username = ""
age = ""
gender = ""

logo_file = "./UI/organaiz_logo_1.png"

# Tamaño deseado de la imagen
l_width = 300
l_height = 200

def starter_screen():
    layout = [
        [sg.Image(filename=logo_file, size=(l_width, l_height))],
        [sg.Text('Bienvenido, primero inicializaremos el agente con tus datos:', font=('Helvetica', 14))],
        [sg.Text('Nombre del usuario:'), sg.InputText(key='-USERNAME-', size=(40,1))],
        [sg.Text('Edad:'), sg.InputText(key='-AGE-', size=(40,1))],
        [sg.Text('Genero:'), sg.InputText(key='-GENDER-', size=(40,1))],
        [sg.Button("Guardar e ir al menu", key="ir_a_menu_boton")],
        [sg.Button("Salir", key="salir_button")]
    ]
    window = sg.Window("Lista de tareas", layout, element_justification='c', size=(640, 480))

    # Bucle principal del programa
    while True:
        event, values = window.Read()
        if event == sg.WIN_CLOSED or event == "salir_button":
            break
        elif event == "ir_a_menu_boton":

            # Obtener los valores ingresados en los campos de texto
            username = values['-USERNAME-']
            age = values['-AGE-']
            gender = values['-GENDER-']

            # Guardar la tarea ingresada en la lista de tareas
            window.Element('-USERNAME-').Update('')
            window.Element('-AGE-').Update('')
            window.Element('-GENDER-').Update('')
            window.Refresh()



            menu_principal()
    # Cerrar la ventana y salir del programa
    window.Close()

# Función para volver al menú principal
def menu_principal():
    # Crear la ventana y los elementos de la GUI
    layout = [
        [sg.Text("Bienvenido " + username + ", escoge una opción", font=('Helvetica', 14))],
        [sg.Button("Agregar tarea por texto", key="agregar_tarea_button")],
        [sg.Button("Agregar tarea por audio", key="agregar_tarea_audio_button")],
        #[sg.Listbox(values=tareas, size=(40, 10), key="tareas_listbox")],
        [sg.Button("Eliminar tarea", key="eliminar_tarea_button")],
        [sg.Button("Ver tareas pendientes", key="ver_tareas_button")],
        [sg.Button("Ver horario sugerido", key="ver_horario_button")],
        [sg.Button("Ver prioridad de tareas", key="ver_prioridad_button")],
        [sg.Button("Ver habitos de vida", key="ver_habitos_button")],
        [sg.Button("Salir", key="salir_button")]
    ]

    window = sg.Window("Lista de tareas", layout, element_justification='c', size=(600, 400))

    # Bucle principal del programa
    while True:
        event, values = window.Read()
        
        if event == sg.WIN_CLOSED or event == "salir_button":
            break
        elif event == "agregar_tarea_button":
            agregar_tarea_por_texto()
        elif event == "agregar_tarea_audio_button":
            agregar_tarea_por_audio()
        elif event == "ver_tareas_button":
            ver_tareas_pendientes()
        elif event == "ver_horario_button":
            ver_horario_sugerido()
        elif event == "ver_prioridad_button":
            ver_prioridad()
        elif event == "ver_habitos_button":
            analiza_habitos()
        elif event == "eliminar_tarea_button":
            eliminar_tarea_page()
            # Eliminar tarea seleccionada de la lista
            #tarea_seleccionada = values["tareas_listbox"][0]
            #tareas.remove(tarea_seleccionada)
            #window.Element("tareas_listbox").Update(values=tareas)

    # Cerrar la ventana y salir del programa
    window.Close()


def agregar_tarea_por_texto():

    tarea ={}
    # Inicializar variable de control para volver al menú principal
    ir_a_menu = False

    # Opciones del select
    task_type_options = {
        1: "Alimentación",
        2: "Aseo",
        3: "Actividad de Mascota",
        4: "Estudio",
        5: "Salud Física",
        6: "Plantas",
        7: "Gustos",
        8: "Actividad Social",
        9: "Actividad de Autocuidado y Orden"
    }

    # Opciones de urgencia (números del 1 al 10)
    urgency_options = [str(i) for i in range(1, 11)]

    # Opciones de urgencia (números del 1 al 10)
    recurrency_options = [str(i) for i in range(1, 8)]

    time_day = {
        1: "Morning", 
        2: "Afternoon"}
    
    # elementos GUI
    layout = [[sg.Text('Ingrese los siguientes datos de la tarea:', font=('Helvetica', 14))],
    [sg.Text('Nombre de la tarea:'), sg.InputText(key='-TASKNAME-', size=(40,1))],
    [sg.Text('Tipo de tarea:'), sg.Combo(list(task_type_options.values()), key='-TASKTYPE-', size=(40, 1))],
    [sg.Text('Tiempo promedio (min):'), sg.InputText(key='-AVGTIME-', size=(40,1))],
    [sg.Text('Urgencia:'), sg.Combo(urgency_options, key='-URGENCY-', size=(40, 1))],
    [sg.Text('Hora de inicio (hh:mm):'), sg.InputText(key='-TIMESTART-', size=(40,1))],
    [sg.Text('Deadline (días):'), sg.InputText(key='-DEADLINE-', size=(40,1))],
    [sg.Text('Ubicación:'), sg.InputText(key='-LOCATION-', size=(40,1))],
    [sg.Text('¿Es un hobby?:'), sg.Checkbox('', key='-ISHOBBY-')],
    [sg.Text('Recurrencia (días):'), sg.Combo(recurrency_options, key='-RECURRENCY-', size=(40,1))],
    [sg.Text('Mejor momento para realizarla:'), sg.Combo(['Morning', 'Afternoon'], key='-BESTON-', default_value='Morning')],
    [sg.Text('Involcura a otra persona?:'), sg.InputText(key='-INVOLVES-', size=(40,1))],
    [sg.Submit('Guardar'), sg.Cancel('Cancelar')]]

    # Creamos la ventana
    window = sg.Window('Registro de tareas', layout, element_justification='c')

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED:
            break
        elif event == 'Cancelar':
            ir_a_menu = True
            break
        elif event == 'Guardar':
            # Obtener el número correspondiente a la opción seleccionada
            task_type_number = next((key for key, value in task_type_options.items() if value == values['-TASKTYPE-']), None)
            # Imprimir el número seleccionado
            print(f"Número seleccionado: {task_type_number}")


            # Guardar la tarea ingresada en la lista de tareas
            tarea = {
                'TaskID': "",
                'Name': values['-TASKNAME-'],
                'TaskType': task_type_number,
                'AvgTime': values['-AVGTIME-'],
                'Urgency': values['-URGENCY-'],
                'TimeStart': values['-TIMESTART-'],
                'Deadline': values['-DEADLINE-'],
                'Location': values['-LOCATION-'],
                'IsHobby': values['-ISHOBBY-'],
                'Recurrency': values['-RECURRENCY-'],
                'BestOn': values['-BESTON-'],
                'Involves': values['-INVOLVES-']
            }
            tarea['TimeStart'] = convertir_hora_a_minutos(tarea['TimeStart'])
            print(tarea)
            agregar_por_texto(tarea)
        window.Element('-TASKNAME-').Update('')
        window.Element('-TASKTYPE-').Update('')
        window.Element('-AVGTIME-').Update('')
        window.Element('-URGENCY-').Update('')
        window.Element('-TIMESTART-').Update('')
        window.Element('-DEADLINE-').Update('')
        window.Element('-LOCATION-').Update('')
        window.Element('-ISHOBBY-').Update('')
        window.Element('-RECURRENCY-').Update('')
        window.Element('-BESTON-').Update('')
        window.Element('-INVOLVES-').Update('')
        window.Refresh()

        # Cerrar la ventana y volver al menú principal
        window.Close()

        if ir_a_menu:
            menu_principal()


def agregar_tarea_por_audio():
    # Inicializar variable de control para volver al menú principal
    ir_a_menu = False

    tarea = {}
    
    # elementos GUI
    layout = [[sg.Text('Ingrese los siguientes datos de la tarea:', font=('Helvetica', 14))],
    [sg.Text('Nombre de la tarea:'), sg.FileBrowse(key='-TASKNAME-', size=(40,1))],
    [sg.Text('Tipo de tarea:'), sg.FileBrowse(key='-TASKTYPE-', size=(40,1))],
    [sg.Text('Tiempo promedio (min):'), sg.FileBrowse(key='-AVGTIME-', size=(40,1))],
    [sg.Text('Urgencia:'), sg.FileBrowse(key='-URGENCY-', size=(40,1))],
    [sg.Text('Hora de inicio (hh:mm):'), sg.FileBrowse(key='-TIMESTART-', size=(40,1))],
    [sg.Text('Deadline (días):'), sg.FileBrowse(key='-DEADLINE-', size=(40,1))],
    [sg.Text('Ubicación:'), sg.FileBrowse(key='-LOCATION-', size=(40,1))],
    [sg.Text('¿Es un hobby?:'), sg.FileBrowse(key='-ISHOBBY-', size=(40,1))],
    [sg.Text('Recurrencia (días):'), sg.FileBrowse(key='-RECURRENCY-', size=(40,1))],
    [sg.Text('Mejor momento para realizarla:'), sg.Combo(['Morning', 'Afternoon'], key='-BESTON-', default_value='Morning')],
    [sg.Text('Involcura a otra persona?:'), sg.FileBrowse(key='-INVOLVES-', size=(40,1))],
    [sg.Submit('Guardar'), sg.Cancel('Cancelar')]]

    # Creamos la ventana
    window = sg.Window('Registro de tareas', layout, element_justification='c')

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED:
            break
        elif event == 'Cancelar':
            ir_a_menu = True
            break
        elif event == 'Guardar':
            # Guardar la tarea ingresada en la lista de tareas
            tarea = {
                'IdTask': '',
                'Nombre': values['-TASKNAME-'],
                'Tipo': values['-TASKTYPE-'],
                'TiempoPromedio': values['-AVGTIME-'],
                'Urgencia': values['-URGENCY-'],
                'HoraDeInicio': values['-TIMESTART-'],
                'Deadline': values['-DEADLINE-'],
                'Ubicacion': values['-LOCATION-'],
                'EsHobby': values['-ISHOBBY-'],
                'Recurrencia': values['-RECURRENCY-'],
                'MejorMomento': values['-BESTON-'],
                'Involucra': values['-INVOLVES-']
            }
        tareas.append(tarea)
        window.Element('-TASKNAME-').Update('')
        window.Element('-TASKTYPE-').Update('')
        window.Element('-AVGTIME-').Update('')
        window.Element('-URGENCY-').Update('')
        window.Element('-TIMESTART-').Update('')
        window.Element('-DEADLINE-').Update('')
        window.Element('-LOCATION-').Update('')
        window.Element('-ISHOBBY-').Update('')
        window.Element('-RECURRENCY-').Update('')
        window.Element('-BESTON-').Update('')
        window.Element('-INVOLVES-').Update('')
        window.Refresh()

        agregar_por_audio(tarea.Tipo, tarea.Nombre, tarea.TiempoPromedio, tarea.Urgencia, tarea.HoraDeInicio , tarea.Deadline, tarea.Ubicacion, tarea.EsHobby, tarea.Recurrencia, tarea.MejorMomento , tarea.Involucra )

        # Cerrar la ventana y volver al menú principal
        window.Close()

        if ir_a_menu:
            menu_principal()

def ver_tareas_pendientes():
    # Creamos una lista con los nombres de las tareas
    task_names = list(dictTasks.keys())
    # Creamos la interfaz
    layout = [
        [sg.Text("Tareas pendientes:")],
        [sg.Listbox(task_names, size=(30, len(task_names)))]
    ]
    window = sg.Window("Tareas pendientes", layout)
    # Esperamos a que el usuario cierre la ventana
    event, values = window.read()
    window.close()

def ver_horario_sugerido():
    crearHorario()
    # Crear la lista de datos
    #data_horario = []
    for tarea in horario.values():
        task_dict = tarea.__dict__
        row = [tarea.name, task_dict['avgTime'], task_dict['urgency'], 
            'Hobby' if task_dict['isHobby'] else 'Not hobby', 
            'Unknown' if task_dict['location'] is None else task_dict['location'],
            task_dict['recurrency']]
        data_horario.append(row)

    # Crear el encabezado de la tabla
    header = ['Task Name', 'Avg Time to Complete', 'Task Urgency', 
            'Is it Hobby', 'Task Location', 'Task Recurrency']

    # Crear la tabla
    table = sg.Table(values=data_horario, headings=header, num_rows=10, 
                    auto_size_columns=True, justification='left',
                    key='-TABLE-', row_height=35)

    # Crear el diseño de la ventana
    layout = [[sg.Text('Horario')],
            [table],
            [sg.Button('Agregar Tarea'), sg.Button('Eliminar Tarea'), sg.Button('Salir')]]

    # Crear la ventana
    window = sg.Window('Horario', layout)

    # Mostrar y actualizar la ventana
    while True:
        event, values = window.read()
        if event in (sg.WINDOW_CLOSED, 'Salir'):
            break
            
    window.close()

def eliminar_tarea_page():
    # Cargar las tareas desde el archivo CSV
    with open('tareas.csv', 'r', newline='') as file:
        reader = csv.DictReader(file)
        tareas = list(reader)

    # Crear el diseño de la ventana
    layout = [
        [sg.Text('Selecciona una tarea para eliminar')],
        [sg.Listbox(values=[f"{tarea['TaskID']}: {tarea['Name']}" for tarea in tareas], key='-TAREAS-', size=(40, 10))],
        [sg.Button('Eliminar'), sg.Button('Salir')]
    ]

    # Crear la ventana
    window = sg.Window('Eliminar Tarea', layout)

    # Leer los eventos e interactuar con la ventana
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Salir':
            break
        elif event == 'Eliminar':
            selected_task = values['-TAREAS-'][0] if values['-TAREAS-'] else None
            if selected_task:
                task_id = selected_task.split(':')[0].strip()
                eliminar_tarea(task_id)
                sg.popup('Tarea eliminada exitosamente', title='Eliminación de Tarea')
                # Actualizar la lista de tareas mostrada en la ventana
                tareas = [tarea for tarea in tareas if tarea['TaskID'] != task_id]
                window['-TAREAS-'].update(values=[f"{tarea['TaskID']}: {tarea['Name']}" for tarea in tareas])

    # Cerrar la ventana
    window.close()

def eliminar_tarea(id_tarea):
    # Abrir el archivo CSV y leer las tareas
    with open('tareas.csv', 'r', newline='') as file:
        reader = csv.DictReader(file)
        tareas = list(reader)

    # Buscar la tarea con el ID especificado
    for tarea in tareas:
        if tarea['TaskID'] == id_tarea:
            # Eliminar la tarea de la lista
            tareas.remove(tarea)
            break

    # Actualizar el archivo CSV con la lista de tareas modificada
    with open('tareas.csv', 'w', newline='') as file:
        fieldnames = ['TaskID', 'TaskType', 'Name', 'AvgTime', 'Urgency', 'TimeStart', 'Deadline', 'Location',
                      'IsHobby', 'Recurrency', 'BestOn', 'Involves', 'Parent']
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(tareas)



def ver_prioridad():
    #sistema_difuso()
    #ordenar_prioridad()

    # Definir una lista de strings que contenga la información que deseas mostrar para cada tarea
    #datos_difusa = []
    for tarea in tareas_ordenadas_prioridad:
        tarea_str = f"- {tarea.name}, con una prioridad de: {str(round(tarea.prioridad, 2))}"
        datos_difusa.append(tarea_str)

    print(datos_difusa)

    # Definir la ventana de PySimpleGUI
    layout = [[sg.Text("En caso de no poder realizar alguna de las tareas en tu horario te recomendamos tomar alguna de alta prioridad.")],
            [sg.Text("A continuación te las listamos en el orden recomendado:")],
            [sg.Listbox(values=datos_difusa, size=(60, 10))],
            [sg.Button("OK")]]

    window = sg.Window("Tareas de alta prioridad", layout)

    # Mostrar la ventana y leer los eventos
    while True:
        event, values = window.read()
        if event == sg.WIN_CLOSED or event == "OK":
            break

    window.close()

def analiza_habitos():

    layout = [
        [sg.Text('Horas en que se publicaron tweets:')],
        [sg.Listbox(values=hour_count, size=(60, 10))],
        [sg.Text(f'La hora en que se publicaron más tweets es: {most_common_hour} (Formato 24 hrs).')]
    ]

    window = sg.Window('Tweets por hora', layout)

    # Mostrar la ventana y leer los eventos
    while True:
        event, values = window.read()
        if event == sg.WIN_CLOSED:
            break

    window.close()

#menu_principal()
starter_screen()
# Out:
# Número seleccionado: 7
# {'TaskID': '', 'Name': 'morir', 'TaskType': 7, 'AvgTime': '20', 'Urgency': '2', 'TimeStart': 945, 'Deadline': '1', 'Location': 'cementerio', 'IsHobby': True, 'Recurrency': '3', 'BestOn': 'Afternoon', 'Involves': ' '}

# %%
#sg.theme_previewer()

# %%
ordenar_tareas_en_arbol("./UI/tareas_all.csv", "./UI/tareas_orden.csv")

# %%
reorganizar_csv_por_task_id("./UI/tareas_orden.csv")
